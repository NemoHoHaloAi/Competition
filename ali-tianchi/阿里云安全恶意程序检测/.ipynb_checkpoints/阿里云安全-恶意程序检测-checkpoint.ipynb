# %% [markdown]
# ## 赛题说明
# 本题目提供的数据来自文件（windows 可执行程序）经过沙箱程序模拟运行后的API指令序列，全为windows二进制可执行程序，经过脱敏处理；
#
# 本题目提供的样本数据均来自于从互联网，其中恶意文件的类型有感染型病毒、木马程序、挖矿程序、DDOS木马、勒索病毒等，数据总计6亿条；
#
# ## 数据说明
# **训练数据**（train.zip）：调用记录近9000万次，文件1万多个（以文件编号汇总），字段描述如下：
#
# 字段 | 类型 | 解释
# -|-|-
# file_id | bigint | 文件编号
# label | bigint | 文件标签，0-正常/1-勒索病毒/2-挖矿程序/3-DDoS木马/4-蠕虫病毒/5-感染型病毒/6-后门程序/7-木马程序
# api | string | 文件调用的API名称
# tid | bigint | 调用API的线程编号
# index | string | 线程中API调用的顺序编号
#
# - 注1：一个文件调用的api数量有可能很多，对于一个tid中调用超过5000个api的文件，我们进行了截断，按照顺序保留了每个tid前5000个api的记录。
# - 注2：不同线程tid之间没有顺序关系，同一个tid里的index由小到大代表调用的先后顺序关系。
# - 注3：index是单个文件在沙箱执行时的全局顺序，由于沙箱执行时间有精度限制，所以会出现一个index上出现同线程或者不同线程都在执行多次api的情况，可以保证同tid内部的顺序，但不保证连续。
#
# **测试数据**（test.zip）：调用记录近8000万次，文件1万多个。
# > 说明：格式除了没有label字段，其他数据规格与训练数据一致。
#
# ## 评测指标
# - 选手的结果文件包含9个字段：file_id(bigint)、和八个分类的预测概率prob0, prob1, prob2, prob3, prob4, prob5 ,prob6,prob7 (类型double，范围在[0,1]之间，精度保留小数点后5位，prob<=0.0我们会替换为1e-6，prob>=1.0我们会替换为1.0-1e-6)。选手必须保证每一行的|prob0+prob1+prob2+prob3+prob4+prob5+prob6+prob7-1.0|<1e-6，且将列名按如下顺序写入提交结果文件的第一行，作为表头：file_id,prob0,prob1,prob2,prob3,prob4,prob5,prob6,prob7。
#
# - 分数采用logloss计算公式

# %% [markdown]
# ## 字段分析
#
# - file_id：表现每个程序文件，其中包含正常与各种异常类型，因此可以通过该字段做分组统计分析；
# - label：训练标签，因此该问题是有监督学习；
# - api：程序调用的api，由于是string类型，需要转为普通离散数据，且只支持连续值的算法此处不适用；
# - tid：通过tid可以分组统计某个文件在某个线程中的调用时序，此处考虑HMM算法求转换概率；
# - index：配合tid进行调用时序统计分析；

# %% [markdown]
# ## 问题分析
#
# 简单讲模型需要预测一个未知文件为各个类别的概率，且概率和为1（接近1），训练数据有标签，因此是有监督学习，8个目标类别，因此是一个有监督多分类问题，目前还没有看过数据，但是通常存在极端的不平衡的情况，异常的文件数量远小于正常的文件，但这里跟普通异常检测不同的在于它需要精确的给出是哪一种异常，而不是简单的区分正常/异常，且需要算法输出的是各个类别的概率，而不是0/1；

# %% [markdown]
# ## 环境

# %%
#coding:utf-8
## 导入模块以及环境设置
import os,sys,time,re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
#有中文出现的情况，需要u'内容'

# %matplotlib inline

# %% [markdown]
# ## 数据加载
#
# 由于数据量很大，训练csv文件2.9G，9000W条记录，1w个文件，因此采用pandas的分段加载方法，只加载部分数据做可视化分析；

# %%
train_path = '../../../../../ali_tianchi_dataset/恶意程序检测/security_train.csv'
test_path = '../../../../../ali_tianchi_dataset/恶意程序检测/security_test.csv'
submit_path = '../../../../../ali_tianchi_dataset/恶意程序检测/security_submit.csv'

# %%
def get_chunks(file_path=train_path, chunksize=100000):
    chunks = pd.read_csv(file_path, chunksize=chunksize)
    return chunksize

# %%
train_data = pd.read_csv(train_path, nrows=9000*10)

# %%
train_data.head(5)
# Out:
#    file_id  label                     api   tid  index
# 0        1      5              LdrLoadDll  2488      0
# 1        1      5  LdrGetProcedureAddress  2488      1
# 2        1      5  LdrGetProcedureAddress  2488      2
# 3        1      5  LdrGetProcedureAddress  2488      3
# 4        1      5  LdrGetProcedureAddress  2488      4

# %% [markdown]
# ## 数据可视化分析

# %% [markdown]
# ### 根据文件id分组

# %%
def groupby_fileid_nolabel(data):
    file_data = pd.DataFrame(columns=['file_id','api_type_count',
                                      'tid_type_count','api_call_count'])
    for name,group in data.groupby('file_id'):
        file_data = file_data.append([{'file_id':name,'api_type_count':len(group.api.unique()),
                                       'tid_type_count':len(group.tid.unique()),
                            'api_call_count':group.tid.count()}], ignore_index=True)
    return file_data

def groupby_fileid(data):
    file_data = pd.DataFrame(columns=['file_id','label','api_type_count',
                                      'tid_type_count','api_call_count'])
    for name,group in data.groupby('file_id'):
        file_data = file_data.append([{'file_id':name,'label':group.label.iloc[0],
                                       'api_type_count':len(group.api.unique()),
                                       'tid_type_count':len(group.tid.unique()),
                            'api_call_count':group.tid.count()}], ignore_index=True)
    return file_data

# %%
file_data = groupby_fileid(train_data)
file_data.head(10)
# Out:
#   file_id label api_type_count tid_type_count api_call_count
# 0       1     5            116             11           6786
# 1       2     2             30              4            816
# 2       3     0             42              1            463
# 3       4     0             51              9           2046
# 4       5     0             65              6          10002
# 5       6     0             62              4           5001
# 6       7     0             83             13           5282
# 7       8     0             24              1            118
# 8       9     0            107             32          18028
# 9      10     0             29              3            205

# %% [markdown]
# ### 根据文件类型分组

# %%
def groupby_label(data):
    label_data = pd.DataFrame(columns=['label','api_type_count','tid_type_count','api_call_count'])
    for name,group in data.groupby('label'):
        label_data = label_data.append([{'label':name,'api_type_count':group.api_type_count.mean(),
                                        'tid_type_count':group.tid_type_count.mean(),
                                       'api_call_count':group.api_call_count.mean()}], ignore_index=True)
    return label_data

# %%
label_data = groupby_label(file_data)
print label_data
# Out:
#   label  api_type_count  tid_type_count  api_call_count
# 0     0       50.416667        6.500000     3901.750000
# 1     1       45.000000        6.000000      480.000000
# 2     2       29.500000        2.500000      538.000000
# 3     5       94.000000       17.333333    11070.666667
# 4     7       76.000000       15.500000     4205.500000

# %% [markdown]
# 文件类型与调用的api类型总数的关系，可以看到差异并不明显；

# %%
plt.bar(list(label_data.label), list(label_data.api_type_count))
# Out:
# <Container object of 5 artists>
# /home/kael/Software/anaconda2/envs/python2/lib/python2.7/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# 文件类型与使用线程个数的关系，可以看到各个类型之间有较大差异；

# %%
plt.bar(list(label_data.label), list(label_data.tid_type_count))
# Out:
# <Container object of 5 artists>

# %% [markdown]
# 文件类型与api调用总次数的关系，可以看到主要分为几个阶段，0,12,3,56,7；

# %%
plt.bar(list(label_data.label), list(label_data.api_call_count))
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### 分析api前缀，通过前缀对api进行分组

# %% [markdown]
# 输出所谓程序调用的api种类总数；

# %%
len(train_data.api.unique())
# Out:
# 188

# %% [markdown]
# 输出所有程序调用的api的前缀总数，api设计中通常前缀意味着同一簇；

# %%
api_list = train_data.api.unique()
api_prefix = []
for api in api_list:
    result = re.search(r'[A-Z]', api[1:])
    if result:
        prefix = api[:result.span()[0]+1]
    else:
        prefix = api
    api_prefix.append(prefix)
api_prefix = set(api_prefix)
print api_prefix
print len(api_prefix)
# Out:
# set(['Process32', 'getaddrinfo', 'Copy', 'Uuid', 'Crypt', 'Create', 'Send', 'ioctlsocket', 'Write', 'Start', 'Internet', 'Encrypt', 'Nt', 'Reg', 'Draw', 'Thread32', 'Http', 'Get', 'Read', 'Enum', 'Unhook', 'Device', 'Delete', 'Cert', 'listen', 'Search', 'S', 'Shell', 'W', 'Module32', 'closesocket', 'socket', 'Load', 'setsockopt', 'Set', 'Co', 'Ole', 'bind', 'Is', 'Global', '__exception__', 'Ldr', 'Rtl', 'Sizeof', 'Open', 'Find'])
# 46

# %% [markdown]
# api分析需要针对api的用途做进一步分类处理，暂时搁置，TODO；

# %% [markdown]
# ## 建模
#
# 1. 读取全部数据；
# 2. 划分数据集；
# 3. 对训练数据，根据文件id分组，根据labe分组；
# 4. 相应字段归一化；
# 5. 训练kNN模型；
# 6. 使用验证数据计算模型得分，k为1；

# %%
train_data = pd.read_csv(train_path)

# %%
file_data = groupby_fileid(train_data)
file_data.head(5)
# Out:
#   file_id label api_type_count tid_type_count api_call_count
# 0       1     5            116             11           6786
# 1       2     2             30              4            816
# 2       3     0             42              1            463
# 3       4     0             51              9           2046
# 4       5     0             65              6          10002

# %%
df = file_data[['api_type_count','tid_type_count','api_call_count']]
df.head(5)
# min/max归一化处理
file_data[['api_type_count','tid_type_count','api_call_count']] = (df - df.min()) / (df.max() - df.min())
file_data = file_data.drop('file_id', axis=1)
file_data.head(5)
# Out:
#   label api_type_count tid_type_count api_call_count
# 0     5       0.680473     0.00509165     0.00763902
# 1     2       0.171598     0.00152749    0.000917583
# 2     0       0.242604              0    0.000520151
# 3     0       0.295858     0.00407332      0.0023024
# 4     0       0.378698     0.00254582      0.0112598

# %% [markdown]
# 由于数据是倾斜的，其中0和5文件很多，其余很少，这里考虑采取过抽样的方式来优化这一问题；

# %%
file_data.groupby('label').count()
# Out:
#        api_type_count  tid_type_count  api_call_count
# label
# 0                4978            4978            4978
# 1                 502             502             502
# 2                1196            1196            1196
# 3                 820             820             820
# 4                 100             100             100
# 5                4289            4289            4289
# 6                 515             515             515
# 7                1487            1487            1487

# %% [markdown]
# 以4000为标准，对1,2,3,4,6,7进行过抽样；

# %%
df0 = file_data[file_data.label==0]
df5 = file_data[file_data.label==5]

df1 = file_data[file_data.label==1]
df1 = pd.concat([df1]*8, ignore_index=True)
df2 = file_data[file_data.label==2]
df2 = pd.concat([df2]*4, ignore_index=True)
df3 = file_data[file_data.label==3]
df3 = pd.concat([df3]*5, ignore_index=True)
df4 = file_data[file_data.label==4]
df4 = pd.concat([df4]*40, ignore_index=True)
df6 = file_data[file_data.label==6]
df6 = pd.concat([df6]*8, ignore_index=True)
df7 = file_data[file_data.label==7]
df7 = pd.concat([df7]*3, ignore_index=True)
file_data = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7], ignore_index=True)
file_data.groupby('label').count()
# Out:
#        api_type_count  tid_type_count  api_call_count
# label
# 0                4978            4978            4978
# 1                4016            4016            4016
# 2                4784            4784            4784
# 3                4100            4100            4100
# 4                4000            4000            4000
# 5                4289            4289            4289
# 6                4120            4120            4120
# 7                4461            4461            4461

# %% [markdown]
# 划分数据集

# %%
from sklearn.cross_validation import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(file_data.drop('label', axis=1),file_data.label, test_size=0.25, random_state=0)
print len(x_train)
print len(x_valid)
# Out:
# 26061
# 8687
# /home/kael/Software/anaconda2/envs/python2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# x_train['label'] = y_train
# x_data = x_train
# label_data = groupby_label(x_data)
# x_train = label_data.drop('label', axis=1)
# y_train = label_data.label
# y_train = pd.DataFrame(y_train, columns=['label'])
# x_train

# %% [markdown]
# x_valid['label'] = y_valid
# x_data = x_valid
# file_data = groupby_fileid(x_data)
# x_valid = file_data.drop(['label','file_id'], axis=1)
# y_valid = file_data.label
# y_valid = pd.DataFrame(y_valid, columns=['label'])

# %% [markdown]
# ### 算法对比

# %% [markdown]
# #### kNN

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

knn = KNN(1)
knn.fit(x_train,y_train.astype('int'))
scores=knn.score(x_valid, y_valid.astype('int'))
print scores
# Out:
# 0.915275699321

# %%
from sklearn.metrics import classification_report
y_pred = knn.predict(x_valid)
print classification_report(y_valid.astype('int'), y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.77      0.81      1223
#           1       0.99      0.99      0.99      1013
#           2       0.94      0.97      0.95      1194
#           3       0.92      0.96      0.94      1041
#           4       0.98      0.99      0.98       992
#           5       0.80      0.75      0.78      1093
#           6       0.95      0.99      0.97      1036
#           7       0.89      0.94      0.92      1095
#
# avg / total       0.91      0.92      0.91      8687

# %%
y_pred = knn.predict(x_valid)
y_pred_list = list(y_pred)
y_valid_list = list(y_valid)
class_result = {}
error_result = {}
for i in range(len(y_pred_list)):
    class_result[y_valid_list[i]] = class_result.get(y_valid_list[i], 0)+1
    if y_pred_list[i] != y_valid_list[i]:
        error_result[y_valid_list[i]] = error_result.get(y_valid_list[i], 0)+1

plt.bar(class_result.keys(), class_result.values())
plt.bar(error_result.keys(), error_result.values())
# Out:
# <Container object of 8 artists>

# %% [markdown]
# #### LGB

# %%
x_train.api_type_count = x_train.api_type_count.astype('float64')
x_train.api_call_count = x_train.api_call_count.astype('float64')
x_train.tid_type_count = x_train.tid_type_count.astype('float64')
y_train = y_train.astype('int')

x_valid.api_type_count = x_valid.api_type_count.astype('float64')
x_valid.api_call_count = x_valid.api_call_count.astype('float64')
x_valid.tid_type_count = x_valid.tid_type_count.astype('float64')
y_valid = y_valid.astype('int')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score
import lightgbm as LGB

train_data_lgb=LGB.Dataset(x_train,label=y_train)
valid_data_lgb=LGB.Dataset(x_valid,label=y_valid)
params = {
    'learning_rate':0.075,
#    'lambda_l1':0.01,
#    'lambda_l2':0.01,
     'n_estimators':3000,
    'early_stopping_rounds':100,
    'max_depth':10,
    'objective':'multiclass',
    'num_class':8}

lgb=LGB.train(params,train_data_lgb,valid_sets=[valid_data_lgb])

print 'lgb params:'+str(params)
# 1、AUC
y_pred_pa = lgb.predict(x_valid)  # !!!注意lgm预测的是分数，类似 sklearn的predict_proba
y_valid_oh = label_binarize(y_valid, classes= [0,1,2,3,4,5,6,7])
print 'lgb auc：', roc_auc_score(y_valid_oh, y_pred_pa, average='micro')

# 2、模型报告
y_pred = y_pred_pa.argmax(axis=1)
print '输出模型报告：'
print(classification_report(y_valid, y_pred))
# Out:
# [1]	valid_0's multi_logloss: 1.95998
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 1.86491
# [3]	valid_0's multi_logloss: 1.78544
# [4]	valid_0's multi_logloss: 1.7168
# [5]	valid_0's multi_logloss: 1.65577
# [6]	valid_0's multi_logloss: 1.60259
# [7]	valid_0's multi_logloss: 1.55439
# [8]	valid_0's multi_logloss: 1.51082
# [9]	valid_0's multi_logloss: 1.47132
# [10]	valid_0's multi_logloss: 1.43474
# [11]	valid_0's multi_logloss: 1.4015
# [12]	valid_0's multi_logloss: 1.3707
# [13]	valid_0's multi_logloss: 1.34269
# [14]	valid_0's multi_logloss: 1.31602
# [15]	valid_0's multi_logloss: 1.2911
# [16]	valid_0's multi_logloss: 1.26808
# [17]	valid_0's multi_logloss: 1.24727
# [18]	valid_0's multi_logloss: 1.22767
# [19]	valid_0's multi_logloss: 1.20938
# [20]	valid_0's multi_logloss: 1.19154
# [21]	valid_0's multi_logloss: 1.17521
# [22]	valid_0's multi_logloss: 1.15984
# [23]	valid_0's multi_logloss: 1.14574
# [24]	valid_0's multi_logloss: 1.13241
# [25]	valid_0's multi_logloss: 1.11958
# [26]	valid_0's multi_logloss: 1.10762
# [27]	valid_0's multi_logloss: 1.09593
# [28]	valid_0's multi_logloss: 1.08449
# [29]	valid_0's multi_logloss: 1.07356
# [30]	valid_0's multi_logloss: 1.06319
# [31]	valid_0's multi_logloss: 1.0529
# [32]	valid_0's multi_logloss: 1.04395
# [33]	valid_0's multi_logloss: 1.03488
# [34]	valid_0's multi_logloss: 1.02627
# [35]	valid_0's multi_logloss: 1.01718
# [36]	valid_0's multi_logloss: 1.00893
# [37]	valid_0's multi_logloss: 1.00139
# [38]	valid_0's multi_logloss: 0.993496
# [39]	valid_0's multi_logloss: 0.986149
# [40]	valid_0's multi_logloss: 0.978779
# [41]	valid_0's multi_logloss: 0.97227
# [42]	valid_0's multi_logloss: 0.966149
# [43]	valid_0's multi_logloss: 0.95967
# [44]	valid_0's multi_logloss: 0.9532
# [45]	valid_0's multi_logloss: 0.947231
# [46]	valid_0's multi_logloss: 0.941422
# [47]	valid_0's multi_logloss: 0.935622
# [48]	valid_0's multi_logloss: 0.930388
# [49]	valid_0's multi_logloss: 0.925057
# [50]	valid_0's multi_logloss: 0.920495
# [51]	valid_0's multi_logloss: 0.915615
# [52]	valid_0's multi_logloss: 0.910778
# [53]	valid_0's multi_logloss: 0.905675
# [54]	valid_0's multi_logloss: 0.90126
# [55]	valid_0's multi_logloss: 0.897261
# [56]	valid_0's multi_logloss: 0.893032
# [57]	valid_0's multi_logloss: 0.888779
# [58]	valid_0's multi_logloss: 0.884901
# [59]	valid_0's multi_logloss: 0.881245
# [60]	valid_0's multi_logloss: 0.878054
# [61]	valid_0's multi_logloss: 0.87355
# [62]	valid_0's multi_logloss: 0.869677
# [63]	valid_0's multi_logloss: 0.865739
# [64]	valid_0's multi_logloss: 0.861991
# [65]	valid_0's multi_logloss: 0.858566
# [66]	valid_0's multi_logloss: 0.854897
# [67]	valid_0's multi_logloss: 0.851495
# [68]	valid_0's multi_logloss: 0.84805
# [69]	valid_0's multi_logloss: 0.844811
# [70]	valid_0's multi_logloss: 0.842018
# [71]	valid_0's multi_logloss: 0.838658
# [72]	valid_0's multi_logloss: 0.835444
# [73]	valid_0's multi_logloss: 0.832446
# [74]	valid_0's multi_logloss: 0.829635
# [75]	valid_0's multi_logloss: 0.826638
# [76]	valid_0's multi_logloss: 0.823764
# [77]	valid_0's multi_logloss: 0.821421
# [78]	valid_0's multi_logloss: 0.818628
# [79]	valid_0's multi_logloss: 0.816176
# [80]	valid_0's multi_logloss: 0.813332
# [81]	valid_0's multi_logloss: 0.810574
# [82]	valid_0's multi_logloss: 0.808134
# [83]	valid_0's multi_logloss: 0.805569
# [84]	valid_0's multi_logloss: 0.803409
# [85]	valid_0's multi_logloss: 0.801602
# [86]	valid_0's multi_logloss: 0.799441
# [87]	valid_0's multi_logloss: 0.7974
# [88]	valid_0's multi_logloss: 0.794735
# [89]	valid_0's multi_logloss: 0.79261
# [90]	valid_0's multi_logloss: 0.790689
# [91]	valid_0's multi_logloss: 0.788446
# [92]	valid_0's multi_logloss: 0.78664
# [93]	valid_0's multi_logloss: 0.784131
# [94]	valid_0's multi_logloss: 0.782279
# [95]	valid_0's multi_logloss: 0.780246
# [96]	valid_0's multi_logloss: 0.778157
# [97]	valid_0's multi_logloss: 0.775965
# [98]	valid_0's multi_logloss: 0.774289
# [99]	valid_0's multi_logloss: 0.772279
# [100]	valid_0's multi_logloss: 0.770381
# [101]	valid_0's multi_logloss: 0.768777
# [102]	valid_0's multi_logloss: 0.766659
# [103]	valid_0's multi_logloss: 0.764667
# [104]	valid_0's multi_logloss: 0.762587
# [105]	valid_0's multi_logloss: 0.76052
# [106]	valid_0's multi_logloss: 0.758686
# [107]	valid_0's multi_logloss: 0.756573
# [108]	valid_0's multi_logloss: 0.75487
# [109]	valid_0's multi_logloss: 0.752802
# [110]	valid_0's multi_logloss: 0.75125
# [111]	valid_0's multi_logloss: 0.749531
# [112]	valid_0's multi_logloss: 0.747994
# [113]	valid_0's multi_logloss: 0.746388
# [114]	valid_0's multi_logloss: 0.744531
# [115]	valid_0's multi_logloss: 0.74302
# [116]	valid_0's multi_logloss: 0.741496
# [117]	valid_0's multi_logloss: 0.739792
# [118]	valid_0's multi_logloss: 0.738207
# [119]	valid_0's multi_logloss: 0.736416
# [120]	valid_0's multi_logloss: 0.734851
# [121]	valid_0's multi_logloss: 0.733165
# [122]	valid_0's multi_logloss: 0.731457
# [123]	valid_0's multi_logloss: 0.729751
# [124]	valid_0's multi_logloss: 0.728073
# [125]	valid_0's multi_logloss: 0.726725
# [126]	valid_0's multi_logloss: 0.725112
# [127]	valid_0's multi_logloss: 0.723495
# [128]	valid_0's multi_logloss: 0.722107
# [129]	valid_0's multi_logloss: 0.720659
# [130]	valid_0's multi_logloss: 0.719544
# [131]	valid_0's multi_logloss: 0.71801
# [132]	valid_0's multi_logloss: 0.716571
# [133]	valid_0's multi_logloss: 0.71528
# [134]	valid_0's multi_logloss: 0.714045
# [135]	valid_0's multi_logloss: 0.712635
# [136]	valid_0's multi_logloss: 0.711365
# [137]	valid_0's multi_logloss: 0.709493
# [138]	valid_0's multi_logloss: 0.708546
# [139]	valid_0's multi_logloss: 0.706697
# [140]	valid_0's multi_logloss: 0.705196
# [141]	valid_0's multi_logloss: 0.703955
# [142]	valid_0's multi_logloss: 0.702029
# [143]	valid_0's multi_logloss: 0.7006
# [144]	valid_0's multi_logloss: 0.699582
# [145]	valid_0's multi_logloss: 0.698542
# [146]	valid_0's multi_logloss: 0.697018
# [147]	valid_0's multi_logloss: 0.695754
# [148]	valid_0's multi_logloss: 0.694538
# [149]	valid_0's multi_logloss: 0.693211
# [150]	valid_0's multi_logloss: 0.69194
# [151]	valid_0's multi_logloss: 0.690582
# [152]	valid_0's multi_logloss: 0.689173
# [153]	valid_0's multi_logloss: 0.687892
# [154]	valid_0's multi_logloss: 0.68633
# [155]	valid_0's multi_logloss: 0.684674
# [156]	valid_0's multi_logloss: 0.683871
# [157]	valid_0's multi_logloss: 0.682211
# [158]	valid_0's multi_logloss: 0.680821
# [159]	valid_0's multi_logloss: 0.679535
# [160]	valid_0's multi_logloss: 0.677833
# [161]	valid_0's multi_logloss: 0.676652
# [162]	valid_0's multi_logloss: 0.675801
# [163]	valid_0's multi_logloss: 0.674246
# [164]	valid_0's multi_logloss: 0.673136
# [165]	valid_0's multi_logloss: 0.671852
# [166]	valid_0's multi_logloss: 0.670535
# [167]	valid_0's multi_logloss: 0.669394
# [168]	valid_0's multi_logloss: 0.668106
# [169]	valid_0's multi_logloss: 0.666582
# [170]	valid_0's multi_logloss: 0.66526
# [171]	valid_0's multi_logloss: 0.663966
# [172]	valid_0's multi_logloss: 0.66261
# [173]	valid_0's multi_logloss: 0.661338
# [174]	valid_0's multi_logloss: 0.660218
# [175]	valid_0's multi_logloss: 0.658823
# [176]	valid_0's multi_logloss: 0.657381
# [177]	valid_0's multi_logloss: 0.65626
# [178]	valid_0's multi_logloss: 0.654839
# [179]	valid_0's multi_logloss: 0.653377
# [180]	valid_0's multi_logloss: 0.65238
# [181]	valid_0's multi_logloss: 0.65128
# [182]	valid_0's multi_logloss: 0.650137
# [183]	valid_0's multi_logloss: 0.648898
# [184]	valid_0's multi_logloss: 0.647702
# [185]	valid_0's multi_logloss: 0.646806
# [186]	valid_0's multi_logloss: 0.645837
# [187]	valid_0's multi_logloss: 0.64452
# [188]	valid_0's multi_logloss: 0.643338
# [189]	valid_0's multi_logloss: 0.642434
# [190]	valid_0's multi_logloss: 0.641426
# [191]	valid_0's multi_logloss: 0.64065
# [192]	valid_0's multi_logloss: 0.639557
# [193]	valid_0's multi_logloss: 0.638609
# [194]	valid_0's multi_logloss: 0.637591
# [195]	valid_0's multi_logloss: 0.636695
# [196]	valid_0's multi_logloss: 0.635958
# [197]	valid_0's multi_logloss: 0.63491
# [198]	valid_0's multi_logloss: 0.633418
# [199]	valid_0's multi_logloss: 0.632254
# [200]	valid_0's multi_logloss: 0.631356
# [201]	valid_0's multi_logloss: 0.630004
# [202]	valid_0's multi_logloss: 0.629098
# [203]	valid_0's multi_logloss: 0.62803
# [204]	valid_0's multi_logloss: 0.626929
# [205]	valid_0's multi_logloss: 0.626346
# [206]	valid_0's multi_logloss: 0.625467
# [207]	valid_0's multi_logloss: 0.624494
# [208]	valid_0's multi_logloss: 0.623569
# [209]	valid_0's multi_logloss: 0.622372
# [210]	valid_0's multi_logloss: 0.621366
# [211]	valid_0's multi_logloss: 0.620354
# [212]	valid_0's multi_logloss: 0.619408
# [213]	valid_0's multi_logloss: 0.618557
# [214]	valid_0's multi_logloss: 0.617694
# [215]	valid_0's multi_logloss: 0.616503
# [216]	valid_0's multi_logloss: 0.615394
# [217]	valid_0's multi_logloss: 0.614425
# [218]	valid_0's multi_logloss: 0.613155
# [219]	valid_0's multi_logloss: 0.612261
# [220]	valid_0's multi_logloss: 0.61128
# [221]	valid_0's multi_logloss: 0.610394
# [222]	valid_0's multi_logloss: 0.609316
# [223]	valid_0's multi_logloss: 0.60851
# [224]	valid_0's multi_logloss: 0.607746
# [225]	valid_0's multi_logloss: 0.607105
# [226]	valid_0's multi_logloss: 0.606155
# [227]	valid_0's multi_logloss: 0.605283
# [228]	valid_0's multi_logloss: 0.604239
# [229]	valid_0's multi_logloss: 0.603521
# [230]	valid_0's multi_logloss: 0.602783
# [231]	valid_0's multi_logloss: 0.601913
# [232]	valid_0's multi_logloss: 0.601235
# [233]	valid_0's multi_logloss: 0.600312
# [234]	valid_0's multi_logloss: 0.599345
# [235]	valid_0's multi_logloss: 0.59838
# [236]	valid_0's multi_logloss: 0.597693
# [237]	valid_0's multi_logloss: 0.596646
# [238]	valid_0's multi_logloss: 0.596055
# [239]	valid_0's multi_logloss: 0.595112
# [240]	valid_0's multi_logloss: 0.594171
# [241]	valid_0's multi_logloss: 0.593377
# [242]	valid_0's multi_logloss: 0.592569
# [243]	valid_0's multi_logloss: 0.591687
# [244]	valid_0's multi_logloss: 0.590665
# [245]	valid_0's multi_logloss: 0.589904
# [246]	valid_0's multi_logloss: 0.58886
# [247]	valid_0's multi_logloss: 0.588189
# [248]	valid_0's multi_logloss: 0.587174
# [249]	valid_0's multi_logloss: 0.586342
# [250]	valid_0's multi_logloss: 0.585813
# [251]	valid_0's multi_logloss: 0.584784
# [252]	valid_0's multi_logloss: 0.584016
# [253]	valid_0's multi_logloss: 0.583293
# [254]	valid_0's multi_logloss: 0.582654
# [255]	valid_0's multi_logloss: 0.581958
# [256]	valid_0's multi_logloss: 0.581144
# [257]	valid_0's multi_logloss: 0.58038
# [258]	valid_0's multi_logloss: 0.579494
# [259]	valid_0's multi_logloss: 0.57843
# [260]	valid_0's multi_logloss: 0.577484
# [261]	valid_0's multi_logloss: 0.576681
# [262]	valid_0's multi_logloss: 0.575836
# [263]	valid_0's multi_logloss: 0.575022
# [264]	valid_0's multi_logloss: 0.574175
# [265]	valid_0's multi_logloss: 0.573371
# [266]	valid_0's multi_logloss: 0.572581
# [267]	valid_0's multi_logloss: 0.5719
# [268]	valid_0's multi_logloss: 0.571273
# [269]	valid_0's multi_logloss: 0.570671
# [270]	valid_0's multi_logloss: 0.570059
# [271]	valid_0's multi_logloss: 0.569324
# [272]	valid_0's multi_logloss: 0.568308
# [273]	valid_0's multi_logloss: 0.567467
# [274]	valid_0's multi_logloss: 0.566708
# [275]	valid_0's multi_logloss: 0.566166
# [276]	valid_0's multi_logloss: 0.565342
# [277]	valid_0's multi_logloss: 0.564599
# [278]	valid_0's multi_logloss: 0.564016
# [279]	valid_0's multi_logloss: 0.563421
# [280]	valid_0's multi_logloss: 0.562741
# [281]	valid_0's multi_logloss: 0.562043
# [282]	valid_0's multi_logloss: 0.561158
# [283]	valid_0's multi_logloss: 0.560414
# [284]	valid_0's multi_logloss: 0.559633
# [285]	valid_0's multi_logloss: 0.558823
# [286]	valid_0's multi_logloss: 0.55803
# [287]	valid_0's multi_logloss: 0.557272
# [288]	valid_0's multi_logloss: 0.556442
# [289]	valid_0's multi_logloss: 0.555736
# [290]	valid_0's multi_logloss: 0.554916
# [291]	valid_0's multi_logloss: 0.554089
# [292]	valid_0's multi_logloss: 0.553587
# [293]	valid_0's multi_logloss: 0.552852
# [294]	valid_0's multi_logloss: 0.552228
# [295]	valid_0's multi_logloss: 0.551631
# [296]	valid_0's multi_logloss: 0.550845
# [297]	valid_0's multi_logloss: 0.550201
# [298]	valid_0's multi_logloss: 0.549513
# [299]	valid_0's multi_logloss: 0.548864
# [300]	valid_0's multi_logloss: 0.548205
# [301]	valid_0's multi_logloss: 0.547633
# [302]	valid_0's multi_logloss: 0.546885
# [303]	valid_0's multi_logloss: 0.546259
# [304]	valid_0's multi_logloss: 0.545463
# [305]	valid_0's multi_logloss: 0.544596
# [306]	valid_0's multi_logloss: 0.543835
# [307]	valid_0's multi_logloss: 0.543167
# [308]	valid_0's multi_logloss: 0.542375
# [309]	valid_0's multi_logloss: 0.541748
# [310]	valid_0's multi_logloss: 0.540797
# [311]	valid_0's multi_logloss: 0.540149
# [312]	valid_0's multi_logloss: 0.539415
# [313]	valid_0's multi_logloss: 0.538625
# [314]	valid_0's multi_logloss: 0.538111
# [315]	valid_0's multi_logloss: 0.537471
# [316]	valid_0's multi_logloss: 0.536699
# [317]	valid_0's multi_logloss: 0.536058
# [318]	valid_0's multi_logloss: 0.535304
# [319]	valid_0's multi_logloss: 0.534892
# [320]	valid_0's multi_logloss: 0.534275
# [321]	valid_0's multi_logloss: 0.533704
# [322]	valid_0's multi_logloss: 0.532963
# [323]	valid_0's multi_logloss: 0.532334
# [324]	valid_0's multi_logloss: 0.531895
# [325]	valid_0's multi_logloss: 0.531054
# [326]	valid_0's multi_logloss: 0.530255
# [327]	valid_0's multi_logloss: 0.529615
# [328]	valid_0's multi_logloss: 0.528984
# [329]	valid_0's multi_logloss: 0.528506
# [330]	valid_0's multi_logloss: 0.527775
# [331]	valid_0's multi_logloss: 0.52729
# [332]	valid_0's multi_logloss: 0.526604
# [333]	valid_0's multi_logloss: 0.526291
# [334]	valid_0's multi_logloss: 0.525611
# [335]	valid_0's multi_logloss: 0.52503
# [336]	valid_0's multi_logloss: 0.524352
# [337]	valid_0's multi_logloss: 0.523813
# [338]	valid_0's multi_logloss: 0.523298
# [339]	valid_0's multi_logloss: 0.522732
# [340]	valid_0's multi_logloss: 0.522154
# [341]	valid_0's multi_logloss: 0.521586
# [342]	valid_0's multi_logloss: 0.520998
# [343]	valid_0's multi_logloss: 0.520448
# [344]	valid_0's multi_logloss: 0.519994
# [345]	valid_0's multi_logloss: 0.519427
# [346]	valid_0's multi_logloss: 0.518782
# [347]	valid_0's multi_logloss: 0.518273
# [348]	valid_0's multi_logloss: 0.517758
# [349]	valid_0's multi_logloss: 0.517
# [350]	valid_0's multi_logloss: 0.516377
# [351]	valid_0's multi_logloss: 0.515902
# [352]	valid_0's multi_logloss: 0.515221
# [353]	valid_0's multi_logloss: 0.514629
# [354]	valid_0's multi_logloss: 0.51411
# [355]	valid_0's multi_logloss: 0.513499
# [356]	valid_0's multi_logloss: 0.512838
# [357]	valid_0's multi_logloss: 0.512315
# [358]	valid_0's multi_logloss: 0.511786
# [359]	valid_0's multi_logloss: 0.511347
# [360]	valid_0's multi_logloss: 0.510884
# [361]	valid_0's multi_logloss: 0.51027
# [362]	valid_0's multi_logloss: 0.509775
# [363]	valid_0's multi_logloss: 0.509139
# [364]	valid_0's multi_logloss: 0.508477
# [365]	valid_0's multi_logloss: 0.507884
# [366]	valid_0's multi_logloss: 0.507277
# [367]	valid_0's multi_logloss: 0.506799
# [368]	valid_0's multi_logloss: 0.506454
# [369]	valid_0's multi_logloss: 0.505891
# [370]	valid_0's multi_logloss: 0.505457
# [371]	valid_0's multi_logloss: 0.504832
# [372]	valid_0's multi_logloss: 0.504572
# [373]	valid_0's multi_logloss: 0.504112
# [374]	valid_0's multi_logloss: 0.50373
# [375]	valid_0's multi_logloss: 0.503126
# [376]	valid_0's multi_logloss: 0.502587
# [377]	valid_0's multi_logloss: 0.502241
# [378]	valid_0's multi_logloss: 0.50187
# [379]	valid_0's multi_logloss: 0.501289
# [380]	valid_0's multi_logloss: 0.500922
# [381]	valid_0's multi_logloss: 0.500428
# [382]	valid_0's multi_logloss: 0.499896
# [383]	valid_0's multi_logloss: 0.499376
# [384]	valid_0's multi_logloss: 0.498709
# [385]	valid_0's multi_logloss: 0.498184
# [386]	valid_0's multi_logloss: 0.497734
# [387]	valid_0's multi_logloss: 0.497279
# [388]	valid_0's multi_logloss: 0.496708
# [389]	valid_0's multi_logloss: 0.49625
# [390]	valid_0's multi_logloss: 0.495729
# [391]	valid_0's multi_logloss: 0.495534
# [392]	valid_0's multi_logloss: 0.494994
# [393]	valid_0's multi_logloss: 0.494469
# [394]	valid_0's multi_logloss: 0.494047
# [395]	valid_0's multi_logloss: 0.493675
# [396]	valid_0's multi_logloss: 0.493287
# [397]	valid_0's multi_logloss: 0.492727
# [398]	valid_0's multi_logloss: 0.49227
# [399]	valid_0's multi_logloss: 0.491777
# [400]	valid_0's multi_logloss: 0.491267
# [401]	valid_0's multi_logloss: 0.490656
# [402]	valid_0's multi_logloss: 0.48999
# [403]	valid_0's multi_logloss: 0.489634
# [404]	valid_0's multi_logloss: 0.489366
# [405]	valid_0's multi_logloss: 0.488823
# [406]	valid_0's multi_logloss: 0.488396
# [407]	valid_0's multi_logloss: 0.487964
# [408]	valid_0's multi_logloss: 0.487413
# [409]	valid_0's multi_logloss: 0.486845
# [410]	valid_0's multi_logloss: 0.48647
# [411]	valid_0's multi_logloss: 0.485971
# [412]	valid_0's multi_logloss: 0.485454
# [413]	valid_0's multi_logloss: 0.484825
# [414]	valid_0's multi_logloss: 0.484317
# [415]	valid_0's multi_logloss: 0.483739
# [416]	valid_0's multi_logloss: 0.483362
# [417]	valid_0's multi_logloss: 0.482919
# [418]	valid_0's multi_logloss: 0.482358
# [419]	valid_0's multi_logloss: 0.481896
# [420]	valid_0's multi_logloss: 0.48135
# [421]	valid_0's multi_logloss: 0.481038
# [422]	valid_0's multi_logloss: 0.480798
# [423]	valid_0's multi_logloss: 0.480155
# [424]	valid_0's multi_logloss: 0.479681
# [425]	valid_0's multi_logloss: 0.479244
# [426]	valid_0's multi_logloss: 0.478754
# [427]	valid_0's multi_logloss: 0.478444
# [428]	valid_0's multi_logloss: 0.478164
# [429]	valid_0's multi_logloss: 0.477855
# [430]	valid_0's multi_logloss: 0.477307
# [431]	valid_0's multi_logloss: 0.476909
# [432]	valid_0's multi_logloss: 0.476651
# [433]	valid_0's multi_logloss: 0.47619
# [434]	valid_0's multi_logloss: 0.475896
# [435]	valid_0's multi_logloss: 0.475355
# [436]	valid_0's multi_logloss: 0.474807
# [437]	valid_0's multi_logloss: 0.474457
# [438]	valid_0's multi_logloss: 0.47399
# [439]	valid_0's multi_logloss: 0.473444
# [440]	valid_0's multi_logloss: 0.473118
# [441]	valid_0's multi_logloss: 0.472701
# [442]	valid_0's multi_logloss: 0.472264
# [443]	valid_0's multi_logloss: 0.471759
# [444]	valid_0's multi_logloss: 0.47137
# [445]	valid_0's multi_logloss: 0.470998
# [446]	valid_0's multi_logloss: 0.470455
# [447]	valid_0's multi_logloss: 0.470082
# [448]	valid_0's multi_logloss: 0.469659
# [449]	valid_0's multi_logloss: 0.469456
# [450]	valid_0's multi_logloss: 0.469059
# [451]	valid_0's multi_logloss: 0.468671
# [452]	valid_0's multi_logloss: 0.468289
# [453]	valid_0's multi_logloss: 0.467888
# [454]	valid_0's multi_logloss: 0.467424
# [455]	valid_0's multi_logloss: 0.467105
# [456]	valid_0's multi_logloss: 0.466746
# [457]	valid_0's multi_logloss: 0.466311
# [458]	valid_0's multi_logloss: 0.465937
# [459]	valid_0's multi_logloss: 0.465554
# [460]	valid_0's multi_logloss: 0.46501
# [461]	valid_0's multi_logloss: 0.464609
# [462]	valid_0's multi_logloss: 0.464167
# [463]	valid_0's multi_logloss: 0.463704
# [464]	valid_0's multi_logloss: 0.463183
# [465]	valid_0's multi_logloss: 0.462664
# [466]	valid_0's multi_logloss: 0.462046
# [467]	valid_0's multi_logloss: 0.461503
# [468]	valid_0's multi_logloss: 0.461016
# [469]	valid_0's multi_logloss: 0.460563
# [470]	valid_0's multi_logloss: 0.460243
# [471]	valid_0's multi_logloss: 0.459877
# [472]	valid_0's multi_logloss: 0.459437
# [473]	valid_0's multi_logloss: 0.45889
# [474]	valid_0's multi_logloss: 0.458433
# [475]	valid_0's multi_logloss: 0.458048
# [476]	valid_0's multi_logloss: 0.457755
# [477]	valid_0's multi_logloss: 0.457348
# [478]	valid_0's multi_logloss: 0.456953
# [479]	valid_0's multi_logloss: 0.456606
# [480]	valid_0's multi_logloss: 0.45616
# [481]	valid_0's multi_logloss: 0.455859
# [482]	valid_0's multi_logloss: 0.455407
# [483]	valid_0's multi_logloss: 0.454973
# [484]	valid_0's multi_logloss: 0.454726
# [485]	valid_0's multi_logloss: 0.454276
# [486]	valid_0's multi_logloss: 0.453766
# [487]	valid_0's multi_logloss: 0.453405
# [488]	valid_0's multi_logloss: 0.453171
# [489]	valid_0's multi_logloss: 0.452825
# [490]	valid_0's multi_logloss: 0.452394
# [491]	valid_0's multi_logloss: 0.451984
# [492]	valid_0's multi_logloss: 0.451664
# [493]	valid_0's multi_logloss: 0.451394
# [494]	valid_0's multi_logloss: 0.450971
# [495]	valid_0's multi_logloss: 0.450567
# [496]	valid_0's multi_logloss: 0.450223
# [497]	valid_0's multi_logloss: 0.449834
# [498]	valid_0's multi_logloss: 0.449521
# [499]	valid_0's multi_logloss: 0.449171
# [500]	valid_0's multi_logloss: 0.448823
# [501]	valid_0's multi_logloss: 0.448423
# [502]	valid_0's multi_logloss: 0.448161
# [503]	valid_0's multi_logloss: 0.447691
# [504]	valid_0's multi_logloss: 0.447333
# [505]	valid_0's multi_logloss: 0.446988
# [506]	valid_0's multi_logloss: 0.446674
# [507]	valid_0's multi_logloss: 0.446294
# [508]	valid_0's multi_logloss: 0.445908
# [509]	valid_0's multi_logloss: 0.445512
# [510]	valid_0's multi_logloss: 0.445225
# [511]	valid_0's multi_logloss: 0.444755
# [512]	valid_0's multi_logloss: 0.444341
# [513]	valid_0's multi_logloss: 0.444059
# [514]	valid_0's multi_logloss: 0.443635
# [515]	valid_0's multi_logloss: 0.443443
# [516]	valid_0's multi_logloss: 0.442918
# [517]	valid_0's multi_logloss: 0.442508
# [518]	valid_0's multi_logloss: 0.442221
# [519]	valid_0's multi_logloss: 0.441837
# [520]	valid_0's multi_logloss: 0.441508
# [521]	valid_0's multi_logloss: 0.441253
# [522]	valid_0's multi_logloss: 0.440932
# [523]	valid_0's multi_logloss: 0.440523
# [524]	valid_0's multi_logloss: 0.440189
# [525]	valid_0's multi_logloss: 0.439919
# [526]	valid_0's multi_logloss: 0.439501
# [527]	valid_0's multi_logloss: 0.439166
# [528]	valid_0's multi_logloss: 0.438698
# [529]	valid_0's multi_logloss: 0.438325
# [530]	valid_0's multi_logloss: 0.43809
# [531]	valid_0's multi_logloss: 0.437879
# [532]	valid_0's multi_logloss: 0.437599
# [533]	valid_0's multi_logloss: 0.437277
# [534]	valid_0's multi_logloss: 0.436939
# [535]	valid_0's multi_logloss: 0.436722
# [536]	valid_0's multi_logloss: 0.436314
# [537]	valid_0's multi_logloss: 0.436077
# [538]	valid_0's multi_logloss: 0.435594
# [539]	valid_0's multi_logloss: 0.435227
# [540]	valid_0's multi_logloss: 0.434913
# [541]	valid_0's multi_logloss: 0.434659
# [542]	valid_0's multi_logloss: 0.434266
# [543]	valid_0's multi_logloss: 0.433874
# [544]	valid_0's multi_logloss: 0.433649
# [545]	valid_0's multi_logloss: 0.433247
# [546]	valid_0's multi_logloss: 0.432932
# [547]	valid_0's multi_logloss: 0.432747
# [548]	valid_0's multi_logloss: 0.432407
# [549]	valid_0's multi_logloss: 0.432108
# [550]	valid_0's multi_logloss: 0.43181
# [551]	valid_0's multi_logloss: 0.431505
# [552]	valid_0's multi_logloss: 0.43117
# [553]	valid_0's multi_logloss: 0.430817
# [554]	valid_0's multi_logloss: 0.430533
# [555]	valid_0's multi_logloss: 0.430227
# [556]	valid_0's multi_logloss: 0.430022
# [557]	valid_0's multi_logloss: 0.429838
# [558]	valid_0's multi_logloss: 0.429625
# [559]	valid_0's multi_logloss: 0.429305
# [560]	valid_0's multi_logloss: 0.428941
# [561]	valid_0's multi_logloss: 0.428591
# [562]	valid_0's multi_logloss: 0.428275
# [563]	valid_0's multi_logloss: 0.427903
# [564]	valid_0's multi_logloss: 0.427567
# [565]	valid_0's multi_logloss: 0.427271
# [566]	valid_0's multi_logloss: 0.426947
# [567]	valid_0's multi_logloss: 0.426507
# [568]	valid_0's multi_logloss: 0.426199
# [569]	valid_0's multi_logloss: 0.425941
# [570]	valid_0's multi_logloss: 0.425624
# [571]	valid_0's multi_logloss: 0.425393
# [572]	valid_0's multi_logloss: 0.42513
# [573]	valid_0's multi_logloss: 0.42492
# [574]	valid_0's multi_logloss: 0.424613
# [575]	valid_0's multi_logloss: 0.424236
# [576]	valid_0's multi_logloss: 0.423947
# [577]	valid_0's multi_logloss: 0.423607
# [578]	valid_0's multi_logloss: 0.423295
# [579]	valid_0's multi_logloss: 0.422995
# [580]	valid_0's multi_logloss: 0.422682
# [581]	valid_0's multi_logloss: 0.422395
# [582]	valid_0's multi_logloss: 0.422117
# [583]	valid_0's multi_logloss: 0.42189
# [584]	valid_0's multi_logloss: 0.42154
# [585]	valid_0's multi_logloss: 0.421195
# [586]	valid_0's multi_logloss: 0.420795
# [587]	valid_0's multi_logloss: 0.420349
# [588]	valid_0's multi_logloss: 0.420042
# [589]	valid_0's multi_logloss: 0.419725
# [590]	valid_0's multi_logloss: 0.41939
# [591]	valid_0's multi_logloss: 0.419079
# [592]	valid_0's multi_logloss: 0.418817
# [593]	valid_0's multi_logloss: 0.418475
# [594]	valid_0's multi_logloss: 0.418168
# [595]	valid_0's multi_logloss: 0.417899
# [596]	valid_0's multi_logloss: 0.417573
# [597]	valid_0's multi_logloss: 0.417233
# [598]	valid_0's multi_logloss: 0.416992
# [599]	valid_0's multi_logloss: 0.416777
# [600]	valid_0's multi_logloss: 0.41653
# [601]	valid_0's multi_logloss: 0.416255
# [602]	valid_0's multi_logloss: 0.415937
# [603]	valid_0's multi_logloss: 0.415629
# [604]	valid_0's multi_logloss: 0.415305
# [605]	valid_0's multi_logloss: 0.414956
# [606]	valid_0's multi_logloss: 0.414688
# [607]	valid_0's multi_logloss: 0.414236
# [608]	valid_0's multi_logloss: 0.413973
# [609]	valid_0's multi_logloss: 0.413703
# [610]	valid_0's multi_logloss: 0.413417
# [611]	valid_0's multi_logloss: 0.412987
# [612]	valid_0's multi_logloss: 0.412572
# [613]	valid_0's multi_logloss: 0.41244
# [614]	valid_0's multi_logloss: 0.412161
# [615]	valid_0's multi_logloss: 0.411909
# [616]	valid_0's multi_logloss: 0.411643
# [617]	valid_0's multi_logloss: 0.411265
# [618]	valid_0's multi_logloss: 0.410895
# [619]	valid_0's multi_logloss: 0.410564
# [620]	valid_0's multi_logloss: 0.410333
# [621]	valid_0's multi_logloss: 0.410064
# [622]	valid_0's multi_logloss: 0.409704
# [623]	valid_0's multi_logloss: 0.409399
# [624]	valid_0's multi_logloss: 0.409103
# [625]	valid_0's multi_logloss: 0.408729
# [626]	valid_0's multi_logloss: 0.40841
# [627]	valid_0's multi_logloss: 0.408093
# [628]	valid_0's multi_logloss: 0.407874
# [629]	valid_0's multi_logloss: 0.407618
# [630]	valid_0's multi_logloss: 0.407213
# [631]	valid_0's multi_logloss: 0.406968
# [632]	valid_0's multi_logloss: 0.406672
# [633]	valid_0's multi_logloss: 0.406436
# [634]	valid_0's multi_logloss: 0.406131
# [635]	valid_0's multi_logloss: 0.405888
# [636]	valid_0's multi_logloss: 0.405652
# [637]	valid_0's multi_logloss: 0.405404
# [638]	valid_0's multi_logloss: 0.405082
# [639]	valid_0's multi_logloss: 0.404859
# [640]	valid_0's multi_logloss: 0.40459
# [641]	valid_0's multi_logloss: 0.404332
# [642]	valid_0's multi_logloss: 0.403995
# [643]	valid_0's multi_logloss: 0.403681
# [644]	valid_0's multi_logloss: 0.403332
# [645]	valid_0's multi_logloss: 0.403124
# [646]	valid_0's multi_logloss: 0.40285
# [647]	valid_0's multi_logloss: 0.402595
# [648]	valid_0's multi_logloss: 0.402311
# [649]	valid_0's multi_logloss: 0.402064
# [650]	valid_0's multi_logloss: 0.401802
# [651]	valid_0's multi_logloss: 0.40145
# [652]	valid_0's multi_logloss: 0.4012
# [653]	valid_0's multi_logloss: 0.401009
# [654]	valid_0's multi_logloss: 0.400716
# [655]	valid_0's multi_logloss: 0.400489
# [656]	valid_0's multi_logloss: 0.400173
# [657]	valid_0's multi_logloss: 0.399956
# [658]	valid_0's multi_logloss: 0.399692
# [659]	valid_0's multi_logloss: 0.399443
# [660]	valid_0's multi_logloss: 0.399202
# [661]	valid_0's multi_logloss: 0.398948
# [662]	valid_0's multi_logloss: 0.398656
# [663]	valid_0's multi_logloss: 0.398428
# [664]	valid_0's multi_logloss: 0.398092
# [665]	valid_0's multi_logloss: 0.39778
# [666]	valid_0's multi_logloss: 0.397536
# [667]	valid_0's multi_logloss: 0.397347
# [668]	valid_0's multi_logloss: 0.397158
# [669]	valid_0's multi_logloss: 0.396935
# [670]	valid_0's multi_logloss: 0.39673
# [671]	valid_0's multi_logloss: 0.396577
# [672]	valid_0's multi_logloss: 0.396308
# [673]	valid_0's multi_logloss: 0.396104
# [674]	valid_0's multi_logloss: 0.395909
# [675]	valid_0's multi_logloss: 0.395769
# [676]	valid_0's multi_logloss: 0.395608
# [677]	valid_0's multi_logloss: 0.395383
# [678]	valid_0's multi_logloss: 0.395091
# [679]	valid_0's multi_logloss: 0.394837
# [680]	valid_0's multi_logloss: 0.394682
# [681]	valid_0's multi_logloss: 0.394346
# [682]	valid_0's multi_logloss: 0.394061
# [683]	valid_0's multi_logloss: 0.393802
# [684]	valid_0's multi_logloss: 0.3936
# [685]	valid_0's multi_logloss: 0.39343
# [686]	valid_0's multi_logloss: 0.393188
# [687]	valid_0's multi_logloss: 0.392847
# [688]	valid_0's multi_logloss: 0.392533
# [689]	valid_0's multi_logloss: 0.392223
# [690]	valid_0's multi_logloss: 0.392027
# [691]	valid_0's multi_logloss: 0.391946
# [692]	valid_0's multi_logloss: 0.391673
# [693]	valid_0's multi_logloss: 0.391459
# [694]	valid_0's multi_logloss: 0.391307
# [695]	valid_0's multi_logloss: 0.39111
# [696]	valid_0's multi_logloss: 0.390979
# [697]	valid_0's multi_logloss: 0.390667
# [698]	valid_0's multi_logloss: 0.390459
# [699]	valid_0's multi_logloss: 0.390234
# [700]	valid_0's multi_logloss: 0.389997
# [701]	valid_0's multi_logloss: 0.389859
# [702]	valid_0's multi_logloss: 0.389628
# [703]	valid_0's multi_logloss: 0.389449
# [704]	valid_0's multi_logloss: 0.389204
# [705]	valid_0's multi_logloss: 0.388969
# [706]	valid_0's multi_logloss: 0.388724
# [707]	valid_0's multi_logloss: 0.388478
# [708]	valid_0's multi_logloss: 0.388163
# [709]	valid_0's multi_logloss: 0.387887
# [710]	valid_0's multi_logloss: 0.387657
# [711]	valid_0's multi_logloss: 0.387409
# [712]	valid_0's multi_logloss: 0.387122
# [713]	valid_0's multi_logloss: 0.386894
# [714]	valid_0's multi_logloss: 0.386749
# [715]	valid_0's multi_logloss: 0.386617
# [716]	valid_0's multi_logloss: 0.38636
# [717]	valid_0's multi_logloss: 0.386169
# [718]	valid_0's multi_logloss: 0.385981
# [719]	valid_0's multi_logloss: 0.385746
# [720]	valid_0's multi_logloss: 0.385625
# [721]	valid_0's multi_logloss: 0.385352
# [722]	valid_0's multi_logloss: 0.385077
# [723]	valid_0's multi_logloss: 0.384847
# [724]	valid_0's multi_logloss: 0.384727
# [725]	valid_0's multi_logloss: 0.384453
# [726]	valid_0's multi_logloss: 0.38422
# [727]	valid_0's multi_logloss: 0.384074
# [728]	valid_0's multi_logloss: 0.383861
# [729]	valid_0's multi_logloss: 0.383606
# [730]	valid_0's multi_logloss: 0.383396
# [731]	valid_0's multi_logloss: 0.383228
# [732]	valid_0's multi_logloss: 0.382934
# [733]	valid_0's multi_logloss: 0.382681
# [734]	valid_0's multi_logloss: 0.382475
# [735]	valid_0's multi_logloss: 0.382297
# [736]	valid_0's multi_logloss: 0.382184
# [737]	valid_0's multi_logloss: 0.381878
# [738]	valid_0's multi_logloss: 0.38162
# [739]	valid_0's multi_logloss: 0.381456
# [740]	valid_0's multi_logloss: 0.381153
# [741]	valid_0's multi_logloss: 0.380897
# [742]	valid_0's multi_logloss: 0.380643
# [743]	valid_0's multi_logloss: 0.380408
# [744]	valid_0's multi_logloss: 0.380184
# [745]	valid_0's multi_logloss: 0.380005
# [746]	valid_0's multi_logloss: 0.37988
# [747]	valid_0's multi_logloss: 0.379667
# [748]	valid_0's multi_logloss: 0.379524
# [749]	valid_0's multi_logloss: 0.379357
# [750]	valid_0's multi_logloss: 0.379247
# [751]	valid_0's multi_logloss: 0.378955
# [752]	valid_0's multi_logloss: 0.378672
# [753]	valid_0's multi_logloss: 0.378528
# [754]	valid_0's multi_logloss: 0.378312
# [755]	valid_0's multi_logloss: 0.378191
# [756]	valid_0's multi_logloss: 0.377951
# [757]	valid_0's multi_logloss: 0.377709
# [758]	valid_0's multi_logloss: 0.377528
# [759]	valid_0's multi_logloss: 0.377203
# [760]	valid_0's multi_logloss: 0.376929
# [761]	valid_0's multi_logloss: 0.376779
# [762]	valid_0's multi_logloss: 0.376676
# [763]	valid_0's multi_logloss: 0.376482
# [764]	valid_0's multi_logloss: 0.376297
# [765]	valid_0's multi_logloss: 0.376124
# [766]	valid_0's multi_logloss: 0.375934
# [767]	valid_0's multi_logloss: 0.375754
# [768]	valid_0's multi_logloss: 0.375713
# [769]	valid_0's multi_logloss: 0.375519
# [770]	valid_0's multi_logloss: 0.375364
# [771]	valid_0's multi_logloss: 0.375147
# [772]	valid_0's multi_logloss: 0.37491
# [773]	valid_0's multi_logloss: 0.374667
# [774]	valid_0's multi_logloss: 0.374462
# [775]	valid_0's multi_logloss: 0.374324
# [776]	valid_0's multi_logloss: 0.374114
# [777]	valid_0's multi_logloss: 0.373997
# [778]	valid_0's multi_logloss: 0.373813
# [779]	valid_0's multi_logloss: 0.373723
# [780]	valid_0's multi_logloss: 0.373587
# [781]	valid_0's multi_logloss: 0.37342
# [782]	valid_0's multi_logloss: 0.373185
# [783]	valid_0's multi_logloss: 0.373102
# [784]	valid_0's multi_logloss: 0.372913
# [785]	valid_0's multi_logloss: 0.372779
# [786]	valid_0's multi_logloss: 0.372571
# [787]	valid_0's multi_logloss: 0.37237
# [788]	valid_0's multi_logloss: 0.372198
# [789]	valid_0's multi_logloss: 0.372035
# [790]	valid_0's multi_logloss: 0.371797
# [791]	valid_0's multi_logloss: 0.371652
# [792]	valid_0's multi_logloss: 0.371573
# [793]	valid_0's multi_logloss: 0.371476
# [794]	valid_0's multi_logloss: 0.371347
# [795]	valid_0's multi_logloss: 0.371193
# [796]	valid_0's multi_logloss: 0.371007
# [797]	valid_0's multi_logloss: 0.370865
# [798]	valid_0's multi_logloss: 0.370722
# [799]	valid_0's multi_logloss: 0.370517
# [800]	valid_0's multi_logloss: 0.370419
# [801]	valid_0's multi_logloss: 0.370325
# [802]	valid_0's multi_logloss: 0.370088
# [803]	valid_0's multi_logloss: 0.369969
# [804]	valid_0's multi_logloss: 0.369832
# [805]	valid_0's multi_logloss: 0.369704
# [806]	valid_0's multi_logloss: 0.369548
# [807]	valid_0's multi_logloss: 0.369398
# [808]	valid_0's multi_logloss: 0.369207
# [809]	valid_0's multi_logloss: 0.369026
# [810]	valid_0's multi_logloss: 0.368885
# [811]	valid_0's multi_logloss: 0.368753
# [812]	valid_0's multi_logloss: 0.368553
# [813]	valid_0's multi_logloss: 0.368342
# [814]	valid_0's multi_logloss: 0.368179
# [815]	valid_0's multi_logloss: 0.368017
# [816]	valid_0's multi_logloss: 0.367803
# [817]	valid_0's multi_logloss: 0.367602
# [818]	valid_0's multi_logloss: 0.367304
# [819]	valid_0's multi_logloss: 0.367102
# [820]	valid_0's multi_logloss: 0.366991
# [821]	valid_0's multi_logloss: 0.366848
# [822]	valid_0's multi_logloss: 0.366652
# [823]	valid_0's multi_logloss: 0.366443
# [824]	valid_0's multi_logloss: 0.366226
# [825]	valid_0's multi_logloss: 0.366036
# [826]	valid_0's multi_logloss: 0.36591
# [827]	valid_0's multi_logloss: 0.365737
# [828]	valid_0's multi_logloss: 0.365468
# [829]	valid_0's multi_logloss: 0.365334
# [830]	valid_0's multi_logloss: 0.365209
# [831]	valid_0's multi_logloss: 0.365049
# [832]	valid_0's multi_logloss: 0.364905
# [833]	valid_0's multi_logloss: 0.36472
# [834]	valid_0's multi_logloss: 0.364608
# [835]	valid_0's multi_logloss: 0.364411
# [836]	valid_0's multi_logloss: 0.36413
# [837]	valid_0's multi_logloss: 0.363973
# [838]	valid_0's multi_logloss: 0.363774
# [839]	valid_0's multi_logloss: 0.363575
# [840]	valid_0's multi_logloss: 0.363386
# [841]	valid_0's multi_logloss: 0.363276
# [842]	valid_0's multi_logloss: 0.363033
# [843]	valid_0's multi_logloss: 0.362855
# [844]	valid_0's multi_logloss: 0.362735
# [845]	valid_0's multi_logloss: 0.36258
# [846]	valid_0's multi_logloss: 0.362397
# [847]	valid_0's multi_logloss: 0.362208
# [848]	valid_0's multi_logloss: 0.362063
# [849]	valid_0's multi_logloss: 0.361855
# [850]	valid_0's multi_logloss: 0.361692
# [851]	valid_0's multi_logloss: 0.361563
# [852]	valid_0's multi_logloss: 0.361402
# [853]	valid_0's multi_logloss: 0.361233
# [854]	valid_0's multi_logloss: 0.360993
# [855]	valid_0's multi_logloss: 0.360882
# [856]	valid_0's multi_logloss: 0.360626
# [857]	valid_0's multi_logloss: 0.360467
# [858]	valid_0's multi_logloss: 0.360317
# [859]	valid_0's multi_logloss: 0.360087
# [860]	valid_0's multi_logloss: 0.359919
# [861]	valid_0's multi_logloss: 0.359737
# [862]	valid_0's multi_logloss: 0.359549
# [863]	valid_0's multi_logloss: 0.359477
# [864]	valid_0's multi_logloss: 0.359325
# [865]	valid_0's multi_logloss: 0.359196
# [866]	valid_0's multi_logloss: 0.359016
# [867]	valid_0's multi_logloss: 0.358916
# [868]	valid_0's multi_logloss: 0.358803
# [869]	valid_0's multi_logloss: 0.35858
# [870]	valid_0's multi_logloss: 0.358421
# [871]	valid_0's multi_logloss: 0.35827
# [872]	valid_0's multi_logloss: 0.358129
# [873]	valid_0's multi_logloss: 0.358007
# [874]	valid_0's multi_logloss: 0.357864
# [875]	valid_0's multi_logloss: 0.357723
# [876]	valid_0's multi_logloss: 0.357606
# [877]	valid_0's multi_logloss: 0.35752
# [878]	valid_0's multi_logloss: 0.357401
# [879]	valid_0's multi_logloss: 0.357279
# [880]	valid_0's multi_logloss: 0.357064
# [881]	valid_0's multi_logloss: 0.356886
# [882]	valid_0's multi_logloss: 0.356786
# [883]	valid_0's multi_logloss: 0.356578
# [884]	valid_0's multi_logloss: 0.356397
# [885]	valid_0's multi_logloss: 0.356226
# [886]	valid_0's multi_logloss: 0.356075
# [887]	valid_0's multi_logloss: 0.355956
# [888]	valid_0's multi_logloss: 0.355845
# [889]	valid_0's multi_logloss: 0.355778
# [890]	valid_0's multi_logloss: 0.355605
# [891]	valid_0's multi_logloss: 0.355501
# [892]	valid_0's multi_logloss: 0.355354
# [893]	valid_0's multi_logloss: 0.355274
# [894]	valid_0's multi_logloss: 0.35522
# [895]	valid_0's multi_logloss: 0.355171
# [896]	valid_0's multi_logloss: 0.355012
# [897]	valid_0's multi_logloss: 0.354835
# [898]	valid_0's multi_logloss: 0.35471
# [899]	valid_0's multi_logloss: 0.354569
# [900]	valid_0's multi_logloss: 0.354415
# [901]	valid_0's multi_logloss: 0.354281
# [902]	valid_0's multi_logloss: 0.354121
# [903]	valid_0's multi_logloss: 0.353992
# [904]	valid_0's multi_logloss: 0.353849
# [905]	valid_0's multi_logloss: 0.353724
# [906]	valid_0's multi_logloss: 0.353573
# [907]	valid_0's multi_logloss: 0.353455
# [908]	valid_0's multi_logloss: 0.353293
# [909]	valid_0's multi_logloss: 0.353207
# [910]	valid_0's multi_logloss: 0.353107
# [911]	valid_0's multi_logloss: 0.353081
# [912]	valid_0's multi_logloss: 0.353011
# [913]	valid_0's multi_logloss: 0.352973
# [914]	valid_0's multi_logloss: 0.352807
# [915]	valid_0's multi_logloss: 0.352707
# [916]	valid_0's multi_logloss: 0.352555
# [917]	valid_0's multi_logloss: 0.352453
# [918]	valid_0's multi_logloss: 0.352305
# [919]	valid_0's multi_logloss: 0.352228
# [920]	valid_0's multi_logloss: 0.352231
# [921]	valid_0's multi_logloss: 0.35217
# [922]	valid_0's multi_logloss: 0.352087
# [923]	valid_0's multi_logloss: 0.351993
# [924]	valid_0's multi_logloss: 0.351904
# [925]	valid_0's multi_logloss: 0.351744
# [926]	valid_0's multi_logloss: 0.351641
# [927]	valid_0's multi_logloss: 0.351576
# [928]	valid_0's multi_logloss: 0.351496
# [929]	valid_0's multi_logloss: 0.351373
# [930]	valid_0's multi_logloss: 0.351227
# [931]	valid_0's multi_logloss: 0.351117
# [932]	valid_0's multi_logloss: 0.351066
# [933]	valid_0's multi_logloss: 0.350899
# [934]	valid_0's multi_logloss: 0.350783
# [935]	valid_0's multi_logloss: 0.350642
# [936]	valid_0's multi_logloss: 0.35046
# [937]	valid_0's multi_logloss: 0.350366
# [938]	valid_0's multi_logloss: 0.350266
# [939]	valid_0's multi_logloss: 0.350074
# [940]	valid_0's multi_logloss: 0.349953
# [941]	valid_0's multi_logloss: 0.349864
# [942]	valid_0's multi_logloss: 0.349728
# [943]	valid_0's multi_logloss: 0.349664
# [944]	valid_0's multi_logloss: 0.349558
# [945]	valid_0's multi_logloss: 0.349448
# [946]	valid_0's multi_logloss: 0.349334
# [947]	valid_0's multi_logloss: 0.349197
# [948]	valid_0's multi_logloss: 0.349089
# [949]	valid_0's multi_logloss: 0.348949
# [950]	valid_0's multi_logloss: 0.348829
# [951]	valid_0's multi_logloss: 0.348755
# [952]	valid_0's multi_logloss: 0.348659
# [953]	valid_0's multi_logloss: 0.348566
# [954]	valid_0's multi_logloss: 0.348475
# [955]	valid_0's multi_logloss: 0.348387
# [956]	valid_0's multi_logloss: 0.348286
# [957]	valid_0's multi_logloss: 0.348197
# [958]	valid_0's multi_logloss: 0.348075
# [959]	valid_0's multi_logloss: 0.347941
# [960]	valid_0's multi_logloss: 0.347862
# [961]	valid_0's multi_logloss: 0.347752
# [962]	valid_0's multi_logloss: 0.34765
# [963]	valid_0's multi_logloss: 0.347525
# [964]	valid_0's multi_logloss: 0.34742
# [965]	valid_0's multi_logloss: 0.347336
# [966]	valid_0's multi_logloss: 0.347254
# [967]	valid_0's multi_logloss: 0.347161
# [968]	valid_0's multi_logloss: 0.347146
# [969]	valid_0's multi_logloss: 0.347087
# [970]	valid_0's multi_logloss: 0.347014
# [971]	valid_0's multi_logloss: 0.347012
# [972]	valid_0's multi_logloss: 0.346862
# [973]	valid_0's multi_logloss: 0.34683
# [974]	valid_0's multi_logloss: 0.346759
# [975]	valid_0's multi_logloss: 0.346634
# [976]	valid_0's multi_logloss: 0.346556
# [977]	valid_0's multi_logloss: 0.346507
# [978]	valid_0's multi_logloss: 0.346404
# [979]	valid_0's multi_logloss: 0.346345
# [980]	valid_0's multi_logloss: 0.346262
# [981]	valid_0's multi_logloss: 0.346118
# [982]	valid_0's multi_logloss: 0.346008
# [983]	valid_0's multi_logloss: 0.345973
# [984]	valid_0's multi_logloss: 0.34591
# [985]	valid_0's multi_logloss: 0.345843
# [986]	valid_0's multi_logloss: 0.345817
# [987]	valid_0's multi_logloss: 0.345697
# [988]	valid_0's multi_logloss: 0.345545
# [989]	valid_0's multi_logloss: 0.345511
# [990]	valid_0's multi_logloss: 0.345371
# [991]	valid_0's multi_logloss: 0.345342
# [992]	valid_0's multi_logloss: 0.345231
# [993]	valid_0's multi_logloss: 0.345094
# [994]	valid_0's multi_logloss: 0.344958
# [995]	valid_0's multi_logloss: 0.344857
# [996]	valid_0's multi_logloss: 0.344796
# [997]	valid_0's multi_logloss: 0.344672
# [998]	valid_0's multi_logloss: 0.344598
# [999]	valid_0's multi_logloss: 0.344458
# [1000]	valid_0's multi_logloss: 0.344272
# [1001]	valid_0's multi_logloss: 0.344192
# [1002]	valid_0's multi_logloss: 0.344177
# [1003]	valid_0's multi_logloss: 0.344106
# [1004]	valid_0's multi_logloss: 0.343936
# [1005]	valid_0's multi_logloss: 0.34381
# [1006]	valid_0's multi_logloss: 0.343677
# [1007]	valid_0's multi_logloss: 0.343559
# [1008]	valid_0's multi_logloss: 0.343386
# [1009]	valid_0's multi_logloss: 0.343227
# [1010]	valid_0's multi_logloss: 0.343095
# [1011]	valid_0's multi_logloss: 0.343009
# [1012]	valid_0's multi_logloss: 0.342937
# [1013]	valid_0's multi_logloss: 0.342877
# [1014]	valid_0's multi_logloss: 0.342797
# [1015]	valid_0's multi_logloss: 0.342668
# [1016]	valid_0's multi_logloss: 0.342483
# [1017]	valid_0's multi_logloss: 0.342425
# [1018]	valid_0's multi_logloss: 0.342328
# [1019]	valid_0's multi_logloss: 0.34223
# [1020]	valid_0's multi_logloss: 0.342028
# [1021]	valid_0's multi_logloss: 0.341904
# [1022]	valid_0's multi_logloss: 0.3418
# [1023]	valid_0's multi_logloss: 0.341693
# [1024]	valid_0's multi_logloss: 0.341618
# [1025]	valid_0's multi_logloss: 0.341477
# [1026]	valid_0's multi_logloss: 0.341459
# [1027]	valid_0's multi_logloss: 0.341359
# [1028]	valid_0's multi_logloss: 0.341198
# [1029]	valid_0's multi_logloss: 0.341054
# [1030]	valid_0's multi_logloss: 0.340932
# [1031]	valid_0's multi_logloss: 0.340842
# [1032]	valid_0's multi_logloss: 0.340774
# [1033]	valid_0's multi_logloss: 0.340692
# [1034]	valid_0's multi_logloss: 0.340584
# [1035]	valid_0's multi_logloss: 0.34051
# [1036]	valid_0's multi_logloss: 0.340334
# [1037]	valid_0's multi_logloss: 0.340321
# [1038]	valid_0's multi_logloss: 0.34017
# [1039]	valid_0's multi_logloss: 0.340029
# [1040]	valid_0's multi_logloss: 0.339818
# [1041]	valid_0's multi_logloss: 0.339761
# [1042]	valid_0's multi_logloss: 0.339583
# [1043]	valid_0's multi_logloss: 0.339464
# [1044]	valid_0's multi_logloss: 0.339386
# [1045]	valid_0's multi_logloss: 0.339288
# [1046]	valid_0's multi_logloss: 0.33916
# [1047]	valid_0's multi_logloss: 0.339025
# [1048]	valid_0's multi_logloss: 0.338884
# [1049]	valid_0's multi_logloss: 0.338698
# [1050]	valid_0's multi_logloss: 0.33855
# [1051]	valid_0's multi_logloss: 0.338487
# [1052]	valid_0's multi_logloss: 0.338378
# [1053]	valid_0's multi_logloss: 0.33826
# [1054]	valid_0's multi_logloss: 0.338191
# [1055]	valid_0's multi_logloss: 0.33817
# [1056]	valid_0's multi_logloss: 0.338066
# [1057]	valid_0's multi_logloss: 0.337934
# [1058]	valid_0's multi_logloss: 0.337787
# [1059]	valid_0's multi_logloss: 0.337695
# [1060]	valid_0's multi_logloss: 0.337557
# [1061]	valid_0's multi_logloss: 0.337491
# [1062]	valid_0's multi_logloss: 0.3374
# [1063]	valid_0's multi_logloss: 0.337273
# [1064]	valid_0's multi_logloss: 0.337215
# [1065]	valid_0's multi_logloss: 0.337127
# [1066]	valid_0's multi_logloss: 0.337013
# [1067]	valid_0's multi_logloss: 0.336881
# [1068]	valid_0's multi_logloss: 0.336773
# [1069]	valid_0's multi_logloss: 0.336678
# [1070]	valid_0's multi_logloss: 0.336578
# [1071]	valid_0's multi_logloss: 0.336459
# [1072]	valid_0's multi_logloss: 0.336383
# [1073]	valid_0's multi_logloss: 0.336287
# [1074]	valid_0's multi_logloss: 0.33617
# [1075]	valid_0's multi_logloss: 0.336048
# [1076]	valid_0's multi_logloss: 0.335956
# [1077]	valid_0's multi_logloss: 0.335896
# [1078]	valid_0's multi_logloss: 0.335746
# [1079]	valid_0's multi_logloss: 0.335591
# [1080]	valid_0's multi_logloss: 0.335439
# [1081]	valid_0's multi_logloss: 0.335318
# [1082]	valid_0's multi_logloss: 0.335169
# [1083]	valid_0's multi_logloss: 0.335081
# [1084]	valid_0's multi_logloss: 0.334965
# [1085]	valid_0's multi_logloss: 0.334832
# [1086]	valid_0's multi_logloss: 0.334733
# [1087]	valid_0's multi_logloss: 0.334616
# [1088]	valid_0's multi_logloss: 0.334462
# [1089]	valid_0's multi_logloss: 0.334324
# [1090]	valid_0's multi_logloss: 0.334219
# [1091]	valid_0's multi_logloss: 0.334173
# [1092]	valid_0's multi_logloss: 0.334039
# [1093]	valid_0's multi_logloss: 0.333996
# [1094]	valid_0's multi_logloss: 0.333873
# [1095]	valid_0's multi_logloss: 0.333757
# [1096]	valid_0's multi_logloss: 0.33372
# [1097]	valid_0's multi_logloss: 0.333637
# [1098]	valid_0's multi_logloss: 0.333537
# [1099]	valid_0's multi_logloss: 0.333415
# [1100]	valid_0's multi_logloss: 0.333353
# [1101]	valid_0's multi_logloss: 0.333236
# [1102]	valid_0's multi_logloss: 0.33313
# [1103]	valid_0's multi_logloss: 0.333041
# [1104]	valid_0's multi_logloss: 0.33295
# [1105]	valid_0's multi_logloss: 0.332844
# [1106]	valid_0's multi_logloss: 0.332791
# [1107]	valid_0's multi_logloss: 0.332694
# [1108]	valid_0's multi_logloss: 0.332598
# [1109]	valid_0's multi_logloss: 0.3325
# [1110]	valid_0's multi_logloss: 0.332418
# [1111]	valid_0's multi_logloss: 0.33237
# [1112]	valid_0's multi_logloss: 0.33233
# [1113]	valid_0's multi_logloss: 0.332311
# [1114]	valid_0's multi_logloss: 0.332231
# [1115]	valid_0's multi_logloss: 0.332106
# [1116]	valid_0's multi_logloss: 0.332005
# [1117]	valid_0's multi_logloss: 0.331939
# [1118]	valid_0's multi_logloss: 0.331892
# [1119]	valid_0's multi_logloss: 0.331836
# [1120]	valid_0's multi_logloss: 0.331807
# [1121]	valid_0's multi_logloss: 0.331698
# [1122]	valid_0's multi_logloss: 0.33163
# [1123]	valid_0's multi_logloss: 0.33155
# [1124]	valid_0's multi_logloss: 0.331457
# [1125]	valid_0's multi_logloss: 0.331358
# [1126]	valid_0's multi_logloss: 0.331328
# [1127]	valid_0's multi_logloss: 0.331256
# [1128]	valid_0's multi_logloss: 0.331134
# [1129]	valid_0's multi_logloss: 0.330984
# [1130]	valid_0's multi_logloss: 0.330884
# [1131]	valid_0's multi_logloss: 0.330815
# [1132]	valid_0's multi_logloss: 0.330781
# [1133]	valid_0's multi_logloss: 0.330662
# [1134]	valid_0's multi_logloss: 0.330552
# [1135]	valid_0's multi_logloss: 0.330464
# [1136]	valid_0's multi_logloss: 0.330363
# [1137]	valid_0's multi_logloss: 0.330244
# [1138]	valid_0's multi_logloss: 0.330137
# [1139]	valid_0's multi_logloss: 0.330053
# [1140]	valid_0's multi_logloss: 0.329924
# [1141]	valid_0's multi_logloss: 0.329885
# [1142]	valid_0's multi_logloss: 0.329801
# [1143]	valid_0's multi_logloss: 0.32974
# [1144]	valid_0's multi_logloss: 0.329617
# [1145]	valid_0's multi_logloss: 0.329528
# [1146]	valid_0's multi_logloss: 0.329403
# [1147]	valid_0's multi_logloss: 0.329379
# [1148]	valid_0's multi_logloss: 0.32928
# [1149]	valid_0's multi_logloss: 0.329145
# [1150]	valid_0's multi_logloss: 0.329052
# [1151]	valid_0's multi_logloss: 0.328939
# [1152]	valid_0's multi_logloss: 0.328832
# [1153]	valid_0's multi_logloss: 0.328683
# [1154]	valid_0's multi_logloss: 0.3286
# [1155]	valid_0's multi_logloss: 0.328564
# [1156]	valid_0's multi_logloss: 0.328496
# [1157]	valid_0's multi_logloss: 0.328357
# [1158]	valid_0's multi_logloss: 0.328289
# [1159]	valid_0's multi_logloss: 0.328219
# [1160]	valid_0's multi_logloss: 0.328096
# [1161]	valid_0's multi_logloss: 0.327975
# [1162]	valid_0's multi_logloss: 0.327883
# [1163]	valid_0's multi_logloss: 0.327821
# [1164]	valid_0's multi_logloss: 0.327675
# [1165]	valid_0's multi_logloss: 0.327587
# [1166]	valid_0's multi_logloss: 0.327483
# [1167]	valid_0's multi_logloss: 0.327367
# [1168]	valid_0's multi_logloss: 0.327225
# [1169]	valid_0's multi_logloss: 0.327139
# [1170]	valid_0's multi_logloss: 0.327099
# [1171]	valid_0's multi_logloss: 0.327074
# [1172]	valid_0's multi_logloss: 0.327052
# [1173]	valid_0's multi_logloss: 0.326899
# [1174]	valid_0's multi_logloss: 0.326771
# [1175]	valid_0's multi_logloss: 0.326723
# [1176]	valid_0's multi_logloss: 0.326639
# [1177]	valid_0's multi_logloss: 0.326548
# [1178]	valid_0's multi_logloss: 0.326444
# [1179]	valid_0's multi_logloss: 0.326346
# [1180]	valid_0's multi_logloss: 0.326241
# [1181]	valid_0's multi_logloss: 0.326189
# [1182]	valid_0's multi_logloss: 0.326084
# [1183]	valid_0's multi_logloss: 0.326027
# [1184]	valid_0's multi_logloss: 0.32598
# [1185]	valid_0's multi_logloss: 0.325927
# [1186]	valid_0's multi_logloss: 0.325827
# [1187]	valid_0's multi_logloss: 0.325752
# [1188]	valid_0's multi_logloss: 0.325636
# [1189]	valid_0's multi_logloss: 0.325553
# [1190]	valid_0's multi_logloss: 0.325506
# [1191]	valid_0's multi_logloss: 0.325473
# [1192]	valid_0's multi_logloss: 0.325324
# [1193]	valid_0's multi_logloss: 0.325227
# [1194]	valid_0's multi_logloss: 0.325203
# [1195]	valid_0's multi_logloss: 0.325119
# [1196]	valid_0's multi_logloss: 0.325054
# [1197]	valid_0's multi_logloss: 0.32499
# [1198]	valid_0's multi_logloss: 0.324922
# [1199]	valid_0's multi_logloss: 0.324808
# [1200]	valid_0's multi_logloss: 0.324747
# ...
# [1680]	valid_0's multi_logloss: 0.305319
# [1681]	valid_0's multi_logloss: 0.305285
# [1682]	valid_0's multi_logloss: 0.305285
# [1683]	valid_0's multi_logloss: 0.305294
# [1684]	valid_0's multi_logloss: 0.305288
# [1685]	valid_0's multi_logloss: 0.30528
# [1686]	valid_0's multi_logloss: 0.305306
# [1687]	valid_0's multi_logloss: 0.305301
# [1688]	valid_0's multi_logloss: 0.305297
# [1689]	valid_0's multi_logloss: 0.305268
# [1690]	valid_0's multi_logloss: 0.305266
# [1691]	valid_0's multi_logloss: 0.305254
# [1692]	valid_0's multi_logloss: 0.30523
# [1693]	valid_0's multi_logloss: 0.305239
# [1694]	valid_0's multi_logloss: 0.305246
# [1695]	valid_0's multi_logloss: 0.305233
# [1696]	valid_0's multi_logloss: 0.305213
# [1697]	valid_0's multi_logloss: 0.305209
# [1698]	valid_0's multi_logloss: 0.305145
# [1699]	valid_0's multi_logloss: 0.305135
# [1700]	valid_0's multi_logloss: 0.305084
# [1701]	valid_0's multi_logloss: 0.305067
# [1702]	valid_0's multi_logloss: 0.305047
# [1703]	valid_0's multi_logloss: 0.305048
# [1704]	valid_0's multi_logloss: 0.305023
# [1705]	valid_0's multi_logloss: 0.305009
# [1706]	valid_0's multi_logloss: 0.304993
# [1707]	valid_0's multi_logloss: 0.304962
# [1708]	valid_0's multi_logloss: 0.304984
# [1709]	valid_0's multi_logloss: 0.304972
# [1710]	valid_0's multi_logloss: 0.304954
# [1711]	valid_0's multi_logloss: 0.304957
# [1712]	valid_0's multi_logloss: 0.304961
# [1713]	valid_0's multi_logloss: 0.304897
# [1714]	valid_0's multi_logloss: 0.304906
# [1715]	valid_0's multi_logloss: 0.304896
# [1716]	valid_0's multi_logloss: 0.304899
# [1717]	valid_0's multi_logloss: 0.304896
# [1718]	valid_0's multi_logloss: 0.304883
# [1719]	valid_0's multi_logloss: 0.304793
# [1720]	valid_0's multi_logloss: 0.304734
# [1721]	valid_0's multi_logloss: 0.304685
# [1722]	valid_0's multi_logloss: 0.304646
# [1723]	valid_0's multi_logloss: 0.304647
# [1724]	valid_0's multi_logloss: 0.304615
# [1725]	valid_0's multi_logloss: 0.304586
# [1726]	valid_0's multi_logloss: 0.304608
# [1727]	valid_0's multi_logloss: 0.304541
# [1728]	valid_0's multi_logloss: 0.304526
# [1729]	valid_0's multi_logloss: 0.3045
# [1730]	valid_0's multi_logloss: 0.304498
# [1731]	valid_0's multi_logloss: 0.304433
# [1732]	valid_0's multi_logloss: 0.304402
# [1733]	valid_0's multi_logloss: 0.304386
# [1734]	valid_0's multi_logloss: 0.304371
# [1735]	valid_0's multi_logloss: 0.304363
# [1736]	valid_0's multi_logloss: 0.30439
# [1737]	valid_0's multi_logloss: 0.304394
# [1738]	valid_0's multi_logloss: 0.304429
# [1739]	valid_0's multi_logloss: 0.304448
# [1740]	valid_0's multi_logloss: 0.304393
# [1741]	valid_0's multi_logloss: 0.30439
# [1742]	valid_0's multi_logloss: 0.304413
# [1743]	valid_0's multi_logloss: 0.30437
# [1744]	valid_0's multi_logloss: 0.304357
# [1745]	valid_0's multi_logloss: 0.304347
# [1746]	valid_0's multi_logloss: 0.304332
# [1747]	valid_0's multi_logloss: 0.304346
# [1748]	valid_0's multi_logloss: 0.304369
# [1749]	valid_0's multi_logloss: 0.304364
# [1750]	valid_0's multi_logloss: 0.304347
# [1751]	valid_0's multi_logloss: 0.304341
# [1752]	valid_0's multi_logloss: 0.304375
# [1753]	valid_0's multi_logloss: 0.30438
# [1754]	valid_0's multi_logloss: 0.30439
# [1755]	valid_0's multi_logloss: 0.30434
# [1756]	valid_0's multi_logloss: 0.304338
# [1757]	valid_0's multi_logloss: 0.304319
# [1758]	valid_0's multi_logloss: 0.304309
# [1759]	valid_0's multi_logloss: 0.304327
# [1760]	valid_0's multi_logloss: 0.304292
# [1761]	valid_0's multi_logloss: 0.304268
# [1762]	valid_0's multi_logloss: 0.304231
# [1763]	valid_0's multi_logloss: 0.304283
# [1764]	valid_0's multi_logloss: 0.304228
# [1765]	valid_0's multi_logloss: 0.304235
# [1766]	valid_0's multi_logloss: 0.304186
# [1767]	valid_0's multi_logloss: 0.304199
# [1768]	valid_0's multi_logloss: 0.304166
# [1769]	valid_0's multi_logloss: 0.304172
# [1770]	valid_0's multi_logloss: 0.304171
# [1771]	valid_0's multi_logloss: 0.304155
# [1772]	valid_0's multi_logloss: 0.30415
# [1773]	valid_0's multi_logloss: 0.304131
# [1774]	valid_0's multi_logloss: 0.304145
# [1775]	valid_0's multi_logloss: 0.304157
# [1776]	valid_0's multi_logloss: 0.304131
# [1777]	valid_0's multi_logloss: 0.304167
# [1778]	valid_0's multi_logloss: 0.304124
# [1779]	valid_0's multi_logloss: 0.304138
# [1780]	valid_0's multi_logloss: 0.30412
# [1781]	valid_0's multi_logloss: 0.304092
# [1782]	valid_0's multi_logloss: 0.304074
# [1783]	valid_0's multi_logloss: 0.304052
# [1784]	valid_0's multi_logloss: 0.304
# [1785]	valid_0's multi_logloss: 0.303988
# [1786]	valid_0's multi_logloss: 0.303974
# [1787]	valid_0's multi_logloss: 0.303964
# [1788]	valid_0's multi_logloss: 0.30393
# [1789]	valid_0's multi_logloss: 0.303946
# [1790]	valid_0's multi_logloss: 0.303919
# [1791]	valid_0's multi_logloss: 0.303897
# [1792]	valid_0's multi_logloss: 0.303862
# [1793]	valid_0's multi_logloss: 0.30384
# [1794]	valid_0's multi_logloss: 0.303792
# [1795]	valid_0's multi_logloss: 0.30382
# [1796]	valid_0's multi_logloss: 0.3038
# [1797]	valid_0's multi_logloss: 0.303774
# [1798]	valid_0's multi_logloss: 0.303765
# [1799]	valid_0's multi_logloss: 0.303751
# [1800]	valid_0's multi_logloss: 0.303712
# [1801]	valid_0's multi_logloss: 0.30372
# [1802]	valid_0's multi_logloss: 0.3037
# [1803]	valid_0's multi_logloss: 0.303643
# [1804]	valid_0's multi_logloss: 0.303687
# [1805]	valid_0's multi_logloss: 0.303699
# [1806]	valid_0's multi_logloss: 0.303665
# [1807]	valid_0's multi_logloss: 0.303628
# [1808]	valid_0's multi_logloss: 0.303615
# [1809]	valid_0's multi_logloss: 0.303618
# [1810]	valid_0's multi_logloss: 0.303637
# [1811]	valid_0's multi_logloss: 0.303607
# [1812]	valid_0's multi_logloss: 0.30362
# [1813]	valid_0's multi_logloss: 0.303631
# [1814]	valid_0's multi_logloss: 0.303628
# [1815]	valid_0's multi_logloss: 0.30363
# [1816]	valid_0's multi_logloss: 0.303624
# [1817]	valid_0's multi_logloss: 0.303557
# [1818]	valid_0's multi_logloss: 0.303533
# [1819]	valid_0's multi_logloss: 0.303507
# [1820]	valid_0's multi_logloss: 0.303491
# [1821]	valid_0's multi_logloss: 0.303439
# [1822]	valid_0's multi_logloss: 0.303434
# [1823]	valid_0's multi_logloss: 0.303412
# [1824]	valid_0's multi_logloss: 0.303419
# [1825]	valid_0's multi_logloss: 0.303379
# [1826]	valid_0's multi_logloss: 0.30339
# [1827]	valid_0's multi_logloss: 0.303378
# [1828]	valid_0's multi_logloss: 0.303322
# [1829]	valid_0's multi_logloss: 0.303263
# [1830]	valid_0's multi_logloss: 0.303249
# [1831]	valid_0's multi_logloss: 0.303221
# [1832]	valid_0's multi_logloss: 0.303217
# [1833]	valid_0's multi_logloss: 0.303203
# [1834]	valid_0's multi_logloss: 0.303199
# [1835]	valid_0's multi_logloss: 0.303197
# [1836]	valid_0's multi_logloss: 0.303146
# [1837]	valid_0's multi_logloss: 0.303107
# [1838]	valid_0's multi_logloss: 0.303089
# [1839]	valid_0's multi_logloss: 0.30312
# [1840]	valid_0's multi_logloss: 0.303088
# [1841]	valid_0's multi_logloss: 0.303067
# [1842]	valid_0's multi_logloss: 0.303076
# [1843]	valid_0's multi_logloss: 0.303075
# [1844]	valid_0's multi_logloss: 0.303064
# [1845]	valid_0's multi_logloss: 0.30303
# [1846]	valid_0's multi_logloss: 0.303026
# [1847]	valid_0's multi_logloss: 0.30302
# [1848]	valid_0's multi_logloss: 0.302998
# [1849]	valid_0's multi_logloss: 0.303004
# [1850]	valid_0's multi_logloss: 0.302963
# [1851]	valid_0's multi_logloss: 0.30293
# [1852]	valid_0's multi_logloss: 0.302943
# [1853]	valid_0's multi_logloss: 0.30295
# [1854]	valid_0's multi_logloss: 0.302936
# [1855]	valid_0's multi_logloss: 0.302895
# [1856]	valid_0's multi_logloss: 0.302886
# [1857]	valid_0's multi_logloss: 0.302816
# [1858]	valid_0's multi_logloss: 0.302763
# [1859]	valid_0's multi_logloss: 0.302769
# [1860]	valid_0's multi_logloss: 0.302771
# [1861]	valid_0's multi_logloss: 0.302787
# [1862]	valid_0's multi_logloss: 0.302758
# [1863]	valid_0's multi_logloss: 0.302729
# [1864]	valid_0's multi_logloss: 0.302745
# [1865]	valid_0's multi_logloss: 0.302726
# [1866]	valid_0's multi_logloss: 0.302747
# [1867]	valid_0's multi_logloss: 0.302738
# [1868]	valid_0's multi_logloss: 0.302673
# [1869]	valid_0's multi_logloss: 0.30269
# [1870]	valid_0's multi_logloss: 0.302691
# [1871]	valid_0's multi_logloss: 0.302714
# [1872]	valid_0's multi_logloss: 0.302719
# [1873]	valid_0's multi_logloss: 0.302704
# [1874]	valid_0's multi_logloss: 0.302716
# [1875]	valid_0's multi_logloss: 0.302748
# [1876]	valid_0's multi_logloss: 0.302709
# [1877]	valid_0's multi_logloss: 0.302677
# [1878]	valid_0's multi_logloss: 0.302641
# [1879]	valid_0's multi_logloss: 0.302666
# [1880]	valid_0's multi_logloss: 0.302657
# [1881]	valid_0's multi_logloss: 0.302614
# [1882]	valid_0's multi_logloss: 0.3026
# [1883]	valid_0's multi_logloss: 0.302594
# [1884]	valid_0's multi_logloss: 0.302603
# [1885]	valid_0's multi_logloss: 0.302572
# [1886]	valid_0's multi_logloss: 0.302515
# [1887]	valid_0's multi_logloss: 0.30249
# [1888]	valid_0's multi_logloss: 0.302457
# [1889]	valid_0's multi_logloss: 0.302441
# [1890]	valid_0's multi_logloss: 0.302443
# [1891]	valid_0's multi_logloss: 0.302403
# [1892]	valid_0's multi_logloss: 0.302378
# [1893]	valid_0's multi_logloss: 0.302367
# [1894]	valid_0's multi_logloss: 0.302311
# [1895]	valid_0's multi_logloss: 0.302295
# [1896]	valid_0's multi_logloss: 0.302326
# [1897]	valid_0's multi_logloss: 0.30233
# [1898]	valid_0's multi_logloss: 0.302337
# [1899]	valid_0's multi_logloss: 0.302302
# [1900]	valid_0's multi_logloss: 0.302306
# [1901]	valid_0's multi_logloss: 0.302324
# [1902]	valid_0's multi_logloss: 0.302295
# [1903]	valid_0's multi_logloss: 0.302273
# [1904]	valid_0's multi_logloss: 0.302228
# [1905]	valid_0's multi_logloss: 0.302221
# [1906]	valid_0's multi_logloss: 0.302208
# [1907]	valid_0's multi_logloss: 0.302186
# [1908]	valid_0's multi_logloss: 0.302154
# [1909]	valid_0's multi_logloss: 0.302127
# [1910]	valid_0's multi_logloss: 0.30212
# [1911]	valid_0's multi_logloss: 0.302143
# [1912]	valid_0's multi_logloss: 0.302114
# [1913]	valid_0's multi_logloss: 0.302108
# [1914]	valid_0's multi_logloss: 0.302038
# [1915]	valid_0's multi_logloss: 0.302013
# [1916]	valid_0's multi_logloss: 0.301968
# [1917]	valid_0's multi_logloss: 0.301954
# [1918]	valid_0's multi_logloss: 0.301953
# [1919]	valid_0's multi_logloss: 0.301948
# [1920]	valid_0's multi_logloss: 0.301936
# [1921]	valid_0's multi_logloss: 0.301924
# [1922]	valid_0's multi_logloss: 0.301953
# [1923]	valid_0's multi_logloss: 0.301966
# [1924]	valid_0's multi_logloss: 0.302011
# [1925]	valid_0's multi_logloss: 0.302072
# [1926]	valid_0's multi_logloss: 0.302093
# [1927]	valid_0's multi_logloss: 0.302133
# [1928]	valid_0's multi_logloss: 0.302136
# [1929]	valid_0's multi_logloss: 0.302177
# [1930]	valid_0's multi_logloss: 0.302164
# [1931]	valid_0's multi_logloss: 0.302171
# [1932]	valid_0's multi_logloss: 0.302126
# [1933]	valid_0's multi_logloss: 0.302114
# [1934]	valid_0's multi_logloss: 0.302065
# [1935]	valid_0's multi_logloss: 0.302082
# [1936]	valid_0's multi_logloss: 0.302052
# [1937]	valid_0's multi_logloss: 0.302052
# [1938]	valid_0's multi_logloss: 0.302041
# [1939]	valid_0's multi_logloss: 0.302024
# [1940]	valid_0's multi_logloss: 0.302039
# [1941]	valid_0's multi_logloss: 0.302009
# [1942]	valid_0's multi_logloss: 0.301995
# [1943]	valid_0's multi_logloss: 0.301992
# [1944]	valid_0's multi_logloss: 0.301993
# [1945]	valid_0's multi_logloss: 0.301989
# [1946]	valid_0's multi_logloss: 0.301941
# [1947]	valid_0's multi_logloss: 0.301959
# [1948]	valid_0's multi_logloss: 0.301925
# [1949]	valid_0's multi_logloss: 0.301894
# [1950]	valid_0's multi_logloss: 0.301848
# [1951]	valid_0's multi_logloss: 0.301831
# [1952]	valid_0's multi_logloss: 0.301856
# [1953]	valid_0's multi_logloss: 0.301867
# [1954]	valid_0's multi_logloss: 0.30189
# [1955]	valid_0's multi_logloss: 0.301942
# [1956]	valid_0's multi_logloss: 0.301944
# [1957]	valid_0's multi_logloss: 0.301937
# [1958]	valid_0's multi_logloss: 0.301938
# [1959]	valid_0's multi_logloss: 0.30191
# [1960]	valid_0's multi_logloss: 0.301907
# [1961]	valid_0's multi_logloss: 0.301923
# [1962]	valid_0's multi_logloss: 0.301909
# [1963]	valid_0's multi_logloss: 0.301918
# [1964]	valid_0's multi_logloss: 0.301954
# [1965]	valid_0's multi_logloss: 0.301945
# [1966]	valid_0's multi_logloss: 0.30192
# [1967]	valid_0's multi_logloss: 0.301929
# [1968]	valid_0's multi_logloss: 0.30198
# [1969]	valid_0's multi_logloss: 0.301941
# [1970]	valid_0's multi_logloss: 0.301946
# [1971]	valid_0's multi_logloss: 0.301933
# [1972]	valid_0's multi_logloss: 0.301887
# [1973]	valid_0's multi_logloss: 0.301863
# [1974]	valid_0's multi_logloss: 0.30191
# [1975]	valid_0's multi_logloss: 0.301882
# [1976]	valid_0's multi_logloss: 0.301861
# [1977]	valid_0's multi_logloss: 0.301851
# [1978]	valid_0's multi_logloss: 0.301868
# [1979]	valid_0's multi_logloss: 0.301848
# [1980]	valid_0's multi_logloss: 0.301876
# [1981]	valid_0's multi_logloss: 0.301853
# [1982]	valid_0's multi_logloss: 0.30186
# [1983]	valid_0's multi_logloss: 0.301887
# [1984]	valid_0's multi_logloss: 0.30189
# [1985]	valid_0's multi_logloss: 0.301846
# [1986]	valid_0's multi_logloss: 0.301896
# [1987]	valid_0's multi_logloss: 0.301853
# [1988]	valid_0's multi_logloss: 0.301882
# [1989]	valid_0's multi_logloss: 0.301913
# [1990]	valid_0's multi_logloss: 0.301918
# [1991]	valid_0's multi_logloss: 0.301956
# [1992]	valid_0's multi_logloss: 0.30195
# [1993]	valid_0's multi_logloss: 0.301982
# [1994]	valid_0's multi_logloss: 0.302011
# [1995]	valid_0's multi_logloss: 0.302057
# [1996]	valid_0's multi_logloss: 0.302062
# [1997]	valid_0's multi_logloss: 0.302058
# [1998]	valid_0's multi_logloss: 0.302045
# [1999]	valid_0's multi_logloss: 0.302062
# [2000]	valid_0's multi_logloss: 0.302083
# [2001]	valid_0's multi_logloss: 0.302061
# [2002]	valid_0's multi_logloss: 0.302066
# [2003]	valid_0's multi_logloss: 0.302081
# [2004]	valid_0's multi_logloss: 0.302058
# [2005]	valid_0's multi_logloss: 0.302089
# [2006]	valid_0's multi_logloss: 0.30208
# [2007]	valid_0's multi_logloss: 0.302133
# [2008]	valid_0's multi_logloss: 0.302165
# [2009]	valid_0's multi_logloss: 0.302168
# [2010]	valid_0's multi_logloss: 0.302189
# [2011]	valid_0's multi_logloss: 0.302148
# [2012]	valid_0's multi_logloss: 0.302176
# [2013]	valid_0's multi_logloss: 0.302153
# [2014]	valid_0's multi_logloss: 0.302146
# [2015]	valid_0's multi_logloss: 0.302181
# [2016]	valid_0's multi_logloss: 0.302148
# [2017]	valid_0's multi_logloss: 0.302114
# [2018]	valid_0's multi_logloss: 0.302083
# [2019]	valid_0's multi_logloss: 0.302047
# [2020]	valid_0's multi_logloss: 0.302044
# [2021]	valid_0's multi_logloss: 0.302076
# [2022]	valid_0's multi_logloss: 0.302089
# [2023]	valid_0's multi_logloss: 0.302114
# [2024]	valid_0's multi_logloss: 0.302131
# [2025]	valid_0's multi_logloss: 0.302135
# [2026]	valid_0's multi_logloss: 0.302136
# [2027]	valid_0's multi_logloss: 0.302122
# [2028]	valid_0's multi_logloss: 0.302107
# [2029]	valid_0's multi_logloss: 0.302046
# [2030]	valid_0's multi_logloss: 0.301993
# [2031]	valid_0's multi_logloss: 0.301998
# [2032]	valid_0's multi_logloss: 0.302038
# [2033]	valid_0's multi_logloss: 0.30202
# [2034]	valid_0's multi_logloss: 0.30206
# [2035]	valid_0's multi_logloss: 0.302028
# [2036]	valid_0's multi_logloss: 0.302035
# [2037]	valid_0's multi_logloss: 0.302042
# [2038]	valid_0's multi_logloss: 0.302031
# [2039]	valid_0's multi_logloss: 0.302043
# [2040]	valid_0's multi_logloss: 0.302068
# [2041]	valid_0's multi_logloss: 0.302086
# [2042]	valid_0's multi_logloss: 0.302091
# [2043]	valid_0's multi_logloss: 0.302095
# [2044]	valid_0's multi_logloss: 0.302056
# [2045]	valid_0's multi_logloss: 0.302037
# [2046]	valid_0's multi_logloss: 0.302048
# [2047]	valid_0's multi_logloss: 0.302016
# [2048]	valid_0's multi_logloss: 0.302027
# [2049]	valid_0's multi_logloss: 0.302006
# [2050]	valid_0's multi_logloss: 0.30196
# [2051]	valid_0's multi_logloss: 0.302023
# Early stopping, best iteration is:
# [1951]	valid_0's multi_logloss: 0.301831
# lgb params:{'num_class': 8, 'learning_rate': 0.075, 'n_estimators': 3000, 'early_stopping_rounds': 100, 'objective': 'multiclass', 'max_depth': 10}
# lgb auc： 0.992622424314
# 输出模型报告：
#              precision    recall  f1-score   support
#
#           0       0.84      0.80      0.82      1223
#           1       0.98      0.98      0.98      1013
#           2       0.93      0.96      0.95      1194
#           3       0.92      0.95      0.93      1041
#           4       0.96      1.00      0.98       992
#           5       0.83      0.74      0.78      1093
#           6       0.94      0.98      0.96      1036
#           7       0.87      0.88      0.87      1095
#
# avg / total       0.91      0.91      0.91      8687

# %% [markdown]
# #### SVM

# %% [markdown]
# ### 模型融合

# %% [markdown]
# ### 模型迭代过程总结
#
# 1. 基于统计方法构建特征V1：
#     1. 做了file id分组统计，构建新特征（api调用类型数、线程数、api调用总数）；
#     2. 准确率接近70%（注意这是个多分类问题，且分类不均衡，看到，类别1,4非常少，而0和5很多，而在预测错误的占比上看出，相对于0和5，其余几类的错误率更高，这也是因为kNN的k取值问题导致数量少的类别较难被选中，这个不平衡带来的问题kNN难以处理，需要考虑后续优化方案）；
#     3. 这只是简单的根据每个文件分组构造特征，最重要的没有利用的信息是index，即api调用时序，这个考虑用HMM来做，今天研究一下怎么用到HMM上，并且还有个问题是要求是输出八个类型的概率，这个可以由kNN的k中的组成比例来实现，不是问题；
#
# 2. 基于统计方法构建特征V2：
#     1. 做了过抽样；
#     2. 得到81%的准确率，明显看到1,2,3,4,6的错误率下降了很多；
#
# 3. 基于统计方法构建特征V3：
#     1. 切换LGB模型，并进行相应的调参，得到91%的准确率；

# %% [markdown]
# ## 测试结果

# %%
train_data = None
file_data = None
x_train, y_train, x_valid, y_valid = None, None, None, None

# %%
test_data = pd.read_csv(test_path)
test_file_data = groupby_fileid_nolabel(test_data)
fileid_data = test_file_data.file_id
test_file_data = test_file_data.drop('file_id', axis=1)

test_file_data.api_type_count = test_file_data.api_type_count.astype('float64')
test_file_data.api_call_count = test_file_data.api_call_count.astype('float64')
test_file_data.tid_type_count = test_file_data.tid_type_count.astype('float64')
fileid_data = fileid_data.astype('int')

# %%
def create_test_result(model, name):
    test_pred = model.predict(test_file_data)
    test_result = pd.DataFrame(columns=['file_id', 'prob0', 'prob1', 'prob2', 'prob3', 
                                        'prob4', 'prob5', 'prob6', 'prob7'])
    for i in range(len(fileid_data)):
        prob = [0]*8
        if name.startswith('knn'):
            prob[test_pred[i]]=1
        elif name.startswith('lgb'):
            prob = test_pred[i]
        test_result = test_result.append([{'file_id':fileid_data.iloc[i],
                                      'prob0':prob[0],'prob1':prob[1],'prob2':prob[2],'prob3':prob[3],
                                      'prob4':prob[4],'prob5':prob[5],'prob6':prob[6],'prob7':prob[7],}], ignore_index=True)
    test_result.to_csv('./result/'+name+'.csv', index=0)
    print './result/'+name+'.csv'

# %%
create_test_result(knn, 'knn_v4')
# Out:
# ./result/knn_v4.csv

# %% [markdown]
# 基于统计方法构建特征V2：
# - 模型：kNN，k为5；
# - 验证集得分：0.81,0.81,0.80；
# - 文件名：knn_v3.csv
# - 提交格式：0/1；
# - 提交得分：

# %% [markdown]
# 基于统计方法构建特征V2：
# - 模型：kNN，k为1；
# - 验证集得分：0.91,0.92,0.91；
# - 文件名：knn_v4.csv
# - 提交格式：0/1；
# - 提交得分：

# %%
create_test_result(lgb, 'lgb_v3')
# Out:
# ./result/lgb_v3.csv

# %% [markdown]
# 基于统计方法构建特征V3：
# - 模型：LGB；
# - 验证集得分：0.91,0.91,0.91；
# - 提交格式：0/1；
# - 提交得分：

# %%
test_data = None
test_file_data = None
fileid_data, test_file_data = None, None

# %% [markdown]
# ## 参考
#
# [HMM](https://hmmlearn.readthedocs.io/en/latest/tutorial.html#building-hmm-and-generating-samples)
# [数据倾斜](https://www.cnblogs.com/gaoss/p/9677466.html)
# [天池高分分享](https://tianchi.aliyun.com/notebook-ai/detail?spm=5176.12586969.1002.3.75c867b5PiAURi&postId=56989)
# [中文文本分类](https://www.jianshu.com/p/dc00a5d597ed)
